# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/TIL DATASET/train (10).csv")
df.head(10)
# Out:
#                                                 text                    target
# 0  Since she was a little girl, Tionna's on and o...      books and literature
# 1  TOURNAMENT: NorCal IN HAND BRACKET SERIES. DET...                    sports
# 2  Mark Salling committed suicide by hanging, acc...                television
# 3            This Beach Is Basically Heaven On Earth                    travel
# 4    Hasbro exec who helped create GI Joe dies at 86    arts and entertainment
# 5             Biggest Bird That Ever Flew Discovered  technology and computing
# 6  Works for Wrangler Bestop XXL Tire Cover It is...                automotive
# 7  Toyota To Settle Justice Department Probe Over...  technology and computing
# 8  Chevy Cruze sales halted for airbag issue, 330...  technology and computing
# 9            What Your Child's New Teacher Must Know           home and garden

# %%
category_counts = df['target'].value_counts()
category_counts
# Out:
# arts and entertainment                       108610
# technology and computing                      78611
# news and politics                             70073
# books and literature                          39193
# automotive                                    38634
# health                                        33444
# careers                                       28624
# pharmaceuticals, conditions, and symptoms     26234
# healthy living                                21185
# movies                                        20887
# family and relationships                      14848
# music and audio                               14171
# business and finance                          12799
# arts and culture                              12042
# style and fashion                             10591
# travel                                         9241
# food and drink                                 8542
# sports                                         8477
# home and garden                                6923
# shopping                                       3128
# hobbies and interests                          2802
# academic interests                             2414
# video gaming                                   1106
# personal finance                                509
# television                                      418
# real estate                                     418
# pets                                            138
# Name: target, dtype: int64

# %%
df_shopping = df[df['target'] == 'shopping']
df_shopping
# Out:
#                                                      text    target
# 135     your hobby modeling shop online - astromodel o...  shopping
# 353                                          sneakstore    shopping
# 360     corona free classifieds - find, buy, sell or r...  shopping
# 1086    indoor toys | farm toys for indoor | tinney's ...  shopping
# 1424    australian owned | premium magnetic toys, diy ...  shopping
# ...                                                   ...       ...
# 573239  pandora jewelry outlet,pandora charms sale cle...  shopping
# 573498                             woburn china & gifts    shopping
# 573526                          - best products for you    shopping
# 573746  buy designer bags, sunglasses, shoes, clothing...  shopping
# 573875   | diecast model cars & collectibles buy onlin...  shopping
#
# [3128 rows x 2 columns]

# %%
num_rows = len(df_shopping)
rows_per_df = num_rows // 4

dfs = []
for i in range(4):
    start_idx = i * rows_per_df
    end_idx = start_idx + rows_per_df
    if i == 3:
        end_idx = num_rows
    df_split = df_travel.iloc[start_idx:end_idx].copy()
    dfs.append(df_split)

df_names = ['df_shopping_1', 'df_shopping_2', 'df_shopping_3', 'df_shopping_4']
for i, df_split in enumerate(dfs):
    globals()[df_names[i]] = df_split

# %%
df_shopping_1
# Out:
#                                                     text  target
# 1      TOURNAMENT: NorCal IN HAND BRACKET SERIES. DET...  sports
# 246    The Touching Moment Eli Manning Almost Lost It...  sports
# 289    Doctors Said This Teen Would Never Run A Marat...  sports
# 333    Belgians Suspect Dirty Water For Laser Sailor ...  sports
# 410    'We would beat em by fifty' Shaq Said Best Lak...  sports
# ...                                                  ...     ...
# 51712  An Angels fan needed to be reminded on Friday ...  sports
# 51848  Trans visibility might be increasing in everyd...  sports
# 51855  Super Bowl ticket prices have dropped dramatic...  sports
# 51865  "Sometimes your best is not enough, and that s...  sports
# 51972  The football competition in the first place in...  sports
#
# [782 rows x 2 columns]

# %%
df_shopping_2
# Out:
#                                                      text  target
# 51985   "Endurance wins. Score one for boxing." Twitte...  sports
# 52005   soccer news, live scores, results & transfers ...  sports
# 52030   finnan says irish can win group steve finnan b...  sports
# 52054   In the game that was expected by many fans of ...  sports
# 52195   Milwaukee Brewers Kill It In This 'Dumb And Du...  sports
# ...                                                   ...     ...
# 105633  Some drugs aren’t banned because they enhance ...  sports
# 105637  This cop is playing to win! D.C. Cop Stiff-Arm...  sports
# 105638  The Browns selected Manziel 22nd overall in th...  sports
# 105900  Nets reserves take the lead once again in easy...  sports
# 105937                                you got dunked on    sports
#
# [782 rows x 2 columns]

# %%
df_shopping_3
# Out:
#                                                      text  target
# 106084                                  Heartbreak In Rio  sports
# 106105  Rob Gronkowski Dances His Way Into NFL Record ...  sports
# 106205  Jerry Richardson is accused of sexually sugges...  sports
# 106238  "I’ve never felt more disrespected in my whole...  sports
# 106303  The way it worked out, however, didn't necessa...  sports
# ...                                                   ...     ...
# 163374  connors  rallying cry for british tennis  do y...  sports
# 163377  Teen Does More Pullups In A Day Than You'll Do...  sports
# 163394  "We just got to rally around each other. I fee...  sports
# 163433            HIGHLIGHTS: Colombia Takes Down Uruguay  sports
# 163437  U.S. Goalkeeper's Gaffe Is A Reminder Of Socce...  sports
#
# [782 rows x 2 columns]

# %%
df_shopping_4
# Out:
#                                                      text  target
# 163518  The best thing about "hot" teams is that they ...  sports
# 163551  giri martial arts supplies & equipment perth &...  sports
# 163652  This CFL Player Takes Unsportsmanlike Conduct ...  sports
# 163733  And he wasn't joking. Bill Walton Thinks Micha...  sports
# 163774  johnson uncertain about euro bid jade johnson ...  sports
# ...                                                   ...     ...
# 215972                    Bryce Harper Knows How To Troll  sports
# 215987  Whether it's really him or not is beside the p...  sports
# 216013  Larry Nassar Was Allowed To See Patients Durin...  sports
# 216025   LIVE: Nigeria Takes On Bosnia-Herzegovina For...  sports
# 216131  Here's How -- And Why -- The Falcons Could Win...  sports
#
# [782 rows x 2 columns]

# %%
import random
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

def get_synonyms_nltk(word):
    synonyms = set()
    for syn in wordnet.synsets(word):
        for lemma in syn.lemmas():
            synonyms.add(lemma.name().replace("_", " "))
    if word in synonyms:
        synonyms.remove(word)
    return list(synonyms)

def synonym_replacement_nltk(text, n=1):
    stop_words = set(stopwords.words("english"))
    words = word_tokenize(text)
    words = [word.lower() for word in words if word.isalpha() and word.lower() not in stop_words]
    augmented_texts = []

    for _ in range(n):
        augmented_text = words.copy()
        for i in range(len(words)):
            if random.random() < 0.15:
                synonyms = get_synonyms_nltk(words[i])
                if synonyms:
                    augmented_text[i] = random.choice(synonyms)
        augmented_texts.append(' '.join(augmented_text))

    return augmented_texts

# %%
augmented_texts = []
for index, row in df_shopping_1.iterrows():
    augmented_text = synonym_replacement_nltk(row['text'])
    augmented_texts.extend(augmented_text)

data_augment = {'category': ['shopping'] * len(augmented_texts),
                'text': augmented_texts}

df_shopping_augment = pd.DataFrame(data_augment)
df_shopping_augment
# Out:
#      category                                               text
# 0    shopping  tournament norcal hand bracket series details ...
# 1    shopping  touching moment eli manning almost lost coach ...
# 2    shopping   doctors said teen would never run marathon wrong
# 3    shopping  Belgian fishy dirty irrigate laser sailor illness
# 4    shopping  would beat em 50 shaq said safe lakers could r...
# ..        ...                                                ...
# 777  shopping  angels fan postulate reminded friday night spe...
# 778  shopping  trans visibility might increasing everyday soc...
# 779  shopping  super bowl fine prices miss dramatically need ...
# 780  shopping  sometimes best enough drive privation better n...
# 781  shopping  football game competition first place burundi ...
#
# [782 rows x 2 columns]

# %%
def random_deletion_spacy(text, n=1, p=0.15):
    doc = nlp(text)
    augmented_texts = []
    for _ in range(n):
        augmented_text = [token.text for token in doc if random.random() > p]
        augmented_texts.append(' '.join(augmented_text))
    return augmented_texts

augmented_texts = []
for index, row in df_shopping_2.iterrows():
    augmented_text = random_deletion_spacy(row['text'])
    augmented_texts.extend(augmented_text)

data_augment = {'category': ['shopping'] * len(augmented_texts),
                'text': augmented_texts}

df_shopping_augment_1 = pd.DataFrame(data_augment)
df_shopping_augment_1
# Out:
#      category                                               text
# 0    shopping  " Endurance wins . one for boxing . Twitter Do...
# 1    shopping  soccer news , live , results | goal.com us the...
# 2    shopping  finnan says can group steve finnan believes th...
# 3    shopping  In the game that was expected by many Handball...
# 4    shopping  Milwaukee Brewers Kill This Dumb And Dumber ' ...
# ..        ...                                                ...
# 777  shopping  Some drugs are n’t banned because they enhance...
# 778  shopping  This cop is playing win ! D.C. Cop Stiff - Arm...
# 779  shopping  The Browns selected Manziel in 2014 NFL The Cl...
# 780  shopping  Nets reserves take the lead once again in easy...
# 781  shopping                                    you dunked on
#
# [782 rows x 2 columns]

# %%
def text_rotation_spacy(text, n=1):
    augmented_texts = []
    sentences = list(nlp(text).sents)
    for _ in range(n):
        random.shuffle(sentences)
        augmented_texts.append(' '.join([sent.text for sent in sentences]))
    return augmented_texts

augmented_texts = []
for index, row in df_shopping_3.iterrows():
    augmented_text = text_rotation_spacy(row['text'])
    augmented_texts.extend(augmented_text)

data_augment = {'category': ['shopping'] * len(augmented_texts),
                'text': augmented_texts}

df_shopping_augment_2 = pd.DataFrame(data_augment)
df_shopping_augment_2
# Out:
#      category                                               text
# 0    shopping                                  Heartbreak In Rio
# 1    shopping  Rob Gronkowski Dances His Way Into NFL Record ...
# 2    shopping  Panthers Owner Puts Team Up For Sale As NFL Pr...
# 3    shopping  "I’ve never felt more disrespected in my whole...
# 4    shopping  After Touchdown (GIF/VIDEO) The way it worked ...
# ..        ...                                                ...
# 777  shopping  you can t be moulded. that s where it that s w...
# 778  shopping  Than You'll Do In A Lifetime Teen Does More Pu...
# 779  shopping  "We just got to rally around each other. It's ...
# 780  shopping            HIGHLIGHTS: Colombia Takes Down Uruguay
# 781  shopping  U.S. Goalkeeper's Gaffe Is A Reminder Of Socce...
#
# [782 rows x 2 columns]

# %%
df_shopping_4[df_shopping_4.text==""]
# Out:
# Empty DataFrame
# Columns: [text, target]
# Index: []

# %%
import random
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

def get_synonyms_nltk(word):
    synonyms = set()
    for syn in wordnet.synsets(word):
        for lemma in syn.lemmas():
            synonyms.add(lemma.name().replace("_", " "))
    if word in synonyms:
        synonyms.remove(word)
    return list(synonyms)

def synonym_replacement_nltk(text, n=1):
    stop_words = set(stopwords.words("english"))
    words = word_tokenize(text)
    words = [word.lower() for word in words if word.isalpha() and word.lower() not in stop_words]
    augmented_texts = []

    for _ in range(n):
        augmented_text = words.copy()
        for i in range(len(words)):
            if random.random() < 0.15:
                synonyms = get_synonyms_nltk(words[i])
                if synonyms:
                    augmented_text[i] = random.choice(synonyms)
        augmented_texts.append(' '.join(augmented_text))

    return augmented_texts

# %%
augmented_texts = []
for index, row in df_shopping_4.iterrows():
    augmented_text = synonym_replacement_nltk(row['text'])
    augmented_texts.extend(augmented_text)

data_augment = {'category': ['shopping'] * len(augmented_texts),
                'text': augmented_texts}

df_shopping_augment_3 = pd.DataFrame(data_augment)
df_shopping_augment_3
# Out:
#      category                                               text
# 0    shopping  outflank matter hot teams eventually cool unfo...
# 1    shopping  giri martial arts supplies equipment perth onl...
# 2    shopping  cfl player takes unsportsmanlike conduct anoth...
# 3    shopping  joking bill walton thinks michael jordan ordin...
# 4    shopping  johnson uncertain euro bidding jade Andrew Joh...
# ..        ...                                                ...
# 777  shopping                           bryce harper knows troll
# 778  shopping  whether really beside point phil jackson city ...
# 779  shopping  larry nassar allowed see patients sexual assau...
# 780  shopping  live Federal Republic of Nigeria takes prime g...
# 781  shopping                    falcons could win super bowlful
#
# [782 rows x 2 columns]

# %%
data_frames = [df_shopping_augment, df_shopping_augment_1, df_shopping_augment_2, df_shopping_augment_3]
df_final_shopping_augment = pd.concat(data_frames, ignore_index=True)

# %%
df_final_shopping_augment.to_csv('df_shopping_augmented.csv', index=False)

# %%
df1=pd.read_csv("df_shopping_augmented.csv")

# %%
df1.shape
# Out:
# (3128, 2)
