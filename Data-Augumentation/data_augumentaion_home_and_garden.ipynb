# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/TIL DATASET/train (10).csv")
df.head(10)
# Out:
#                                                 text                    target
# 0  Since she was a little girl, Tionna's on and o...      books and literature
# 1  TOURNAMENT: NorCal IN HAND BRACKET SERIES. DET...                    sports
# 2  Mark Salling committed suicide by hanging, acc...                television
# 3            This Beach Is Basically Heaven On Earth                    travel
# 4    Hasbro exec who helped create GI Joe dies at 86    arts and entertainment
# 5             Biggest Bird That Ever Flew Discovered  technology and computing
# 6  Works for Wrangler Bestop XXL Tire Cover It is...                automotive
# 7  Toyota To Settle Justice Department Probe Over...  technology and computing
# 8  Chevy Cruze sales halted for airbag issue, 330...  technology and computing
# 9            What Your Child's New Teacher Must Know           home and garden

# %%
df_home_and_garden= df[df['target'] == 'home and garden']
df_home_and_garden
# Out:
#                                                      text           target
# 9                 What Your Child's New Teacher Must Know  home and garden
# 68      Exasperated Mom Issues PSA About What To Say T...  home and garden
# 90      It's a relief to clear all that packing materi...  home and garden
# 223     Yes, this is real. Knitting Clock: The ‘365' T...  home and garden
# 288     What Changing Diapers Taught Me About Being A ...  home and garden
# ...                                                   ...              ...
# 573733  Watch Mister Rogers Defend Public Programming ...  home and garden
# 573739                   #TalkToMe Meet the Mildon Family  home and garden
# 573843                                   baat design -     home and garden
# 573961  Dancing requires physical awareness, precision...  home and garden
# 573983   Raising a Creative Genius on the Autism Spectrum  home and garden
#
# [6923 rows x 2 columns]

# %%
num_rows = len(df_home_and_garden)
rows_per_df = num_rows // 3

dfs = []
for i in range(3):
    start_idx = i * rows_per_df
    end_idx = start_idx + rows_per_df
    if i == 3:
        end_idx = num_rows
    df_split = df_home_and_garden.iloc[start_idx:end_idx].copy()
    dfs.append(df_split)

df_names = ['df_home_and_garden_1', 'df_home_and_garden_2', 'df_home_and_garden_3']
for i, df_split in enumerate(dfs):
    globals()[df_names[i]] = df_split

# %%
df_home_and_garden_1
# Out:
#                                                      text           target
# 9                 What Your Child's New Teacher Must Know  home and garden
# 68      Exasperated Mom Issues PSA About What To Say T...  home and garden
# 90      It's a relief to clear all that packing materi...  home and garden
# 223     Yes, this is real. Knitting Clock: The ‘365' T...  home and garden
# 288     What Changing Diapers Taught Me About Being A ...  home and garden
# ...                                                   ...              ...
# 188180  superwareshop srithai superware : ศรีไทยซุปเปอ...  home and garden
# 188182          43 Life Lessons I Shared With My Daughter  home and garden
# 188210  Have something to say? Check out HuffPost Home...  home and garden
# 188228  Click through our slideshow to see other Insta...  home and garden
# 188412  Hypoallergenic bedding is critical for a numbe...  home and garden
#
# [2307 rows x 2 columns]

# %%
df_home_and_garden_2
# Out:
#                                                      text           target
# 188466  The incredible features that could be yours --...  home and garden
# 188541  Great as an art medium, produce saver and more...  home and garden
# 188558  As we slowly move into the cooler weather, you...  home and garden
# 188593  With the release of Beyond Chic: Great Fashion...  home and garden
# 188606  We admit it, sometimes we wish we could DIY ev...  home and garden
# ...                                                   ...              ...
# 378761  And here's even more stuff in mason jars... 4....  home and garden
# 378773  Do you have a home story idea or tip? Email us...  home and garden
# 378790  The Best Long-Distance Mother's Day Gifts For ...  home and garden
# 378806  lovestyle - the best furniture deals for may 2...  home and garden
# 378933  What To Watch On Netflix Thats New This Week ...  home and garden
#
# [2307 rows x 2 columns]

# %%
df_home_and_garden_3
# Out:
#                                                      text           target
# 378942         mm interior design fashion meets interiors  home and garden
# 379054  lynne's gifts from the heart a blog of home de...  home and garden
# 379294  ** Take a look at the video above for tips on ...  home and garden
# 379316  It's been a long winter, but I don't have to t...  home and garden
# 379393  Like ketchup... and oatmeal. 10 Unexpected Nat...  home and garden
# ...                                                   ...              ...
# 573541  Today's clever kitchen designers have storage ...  home and garden
# 573701  Why Zoe Saldana Is Cool Buying Her Sons' Cloth...  home and garden
# 573733  Watch Mister Rogers Defend Public Programming ...  home and garden
# 573739                   #TalkToMe Meet the Mildon Family  home and garden
# 573843                                   baat design -     home and garden
#
# [2307 rows x 2 columns]

# %%
import random
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

def get_synonyms_nltk(word):
    synonyms = set()
    for syn in wordnet.synsets(word):
        for lemma in syn.lemmas():
            synonyms.add(lemma.name().replace("_", " "))
    if word in synonyms:
        synonyms.remove(word)
    return list(synonyms)

def synonym_replacement_nltk(text, n=1):
    stop_words = set(stopwords.words("english"))
    words = word_tokenize(text)
    words = [word.lower() for word in words if word.isalpha() and word.lower() not in stop_words]
    augmented_texts = []

    for _ in range(n):
        augmented_text = words.copy()
        for i in range(len(words)):
            if random.random() < 0.15:
                synonyms = get_synonyms_nltk(words[i])
                if synonyms:
                    augmented_text[i] = random.choice(synonyms)
        augmented_texts.append(' '.join(augmented_text))

    return augmented_texts

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
augmented_texts = []
for index, row in df_home_and_garden_1.iterrows():
    augmented_text = synonym_replacement_nltk(row['text'])
    augmented_texts.extend(augmented_text)

data_augment = {'category': ['home and garden'] * len(augmented_texts),
                'text': augmented_texts}

df_home_and_garden_augment = pd.DataFrame(data_augment)
df_home_and_garden_augment
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
#              category                                               text
# 0     home and garden                        child new teacher must know
# 1     home and garden  exasperated momma issues psa enjoin fraught women
# 2     home and garden  relief clear packing substantial new home fina...
# 3     home and garden  yes real knitting clock ticker creates scarf j...
# 4     home and garden                     changing diapers taught father
# ...               ...                                                ...
# 2302  home and garden  superwareshop srithai superware whorl lock sho...
# 2303  home and garden                           living moral shared girl
# ...

# %%
# !pip install spacy
# !python -m spacy download en_core_web_lg
# Out:
# ...
# 2023-08-07 21:58:46.888283: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-07 21:58:47.922963: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 2.3 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
import spacy

# Load the 'en_core_web_lg' model
nlp = spacy.load('en_core_web_lg')

# Rest of your code using the 'nlp' object

# %%
def random_deletion_spacy(text, n=1, p=0.15):
    doc = nlp(text)
    augmented_texts = []
    for _ in range(n):
        augmented_text = [token.text for token in doc if random.random() > p]
        augmented_texts.append(' '.join(augmented_text))
    return augmented_texts

augmented_texts = []
for index, row in df_home_and_garden_2.iterrows():
    augmented_text = random_deletion_spacy(row['text'])
    augmented_texts.extend(augmented_text)

data_augment = {'category': ['home and garden'] * len(augmented_texts),
                'text': augmented_texts}

df_home_and_garden_augment_1 = pd.DataFrame(data_augment)
df_home_and_garden_augment_1
# Out:
#              category                                               text
# 0     home and garden  The features that could be price is right . Th...
# 1     home and garden  Great an art , produce saver and more ! Ideas ...
# 2     home and garden  we slowly move into the cooler weather your sp...
# 3     home and garden  With the release Beyond Chic : Great at ( $ 51...
# 4     home and garden  it , sometimes we could DIY everything . the r...
# ...               ...                                                ...
# 2302  home and garden  And even more stuff in mason jars ... . Vodka ...
# 2303  home and garden  you have a home story idea or tip Email at hom...
# 2304  home and garden  The Best - Distance Mother 's Day Gifts For Mo...
# 2305  home and garden  lovestyle - the furniture deals for may 2022 f...
# 2306  home and garden      What To Watch On Netflix New This Week ( 17 -
#
# [2307 rows x 2 columns]

# %%
def text_rotation_spacy(text, n=1):
    augmented_texts = []
    sentences = list(nlp(text).sents)
    for _ in range(n):
        random.shuffle(sentences)
        augmented_texts.append(' '.join([sent.text for sent in sentences]))
    return augmented_texts

augmented_texts = []
for index, row in df_home_and_garden_3.iterrows():
    augmented_text = text_rotation_spacy(row['text'])
    augmented_texts.extend(augmented_text)

data_augment = {'category': ['home and garden'] * len(augmented_texts),
                'text': augmented_texts}

df_home_and_garden_augment_2= pd.DataFrame(data_augment)
df_home_and_garden_augment_2
# Out:
#              category                                               text
# 0     home and garden         mm interior design fashion meets interiors
# 1     home and garden  surviving the loss of my husband. lynne's gift...
# 2     home and garden  ** Take a look at the video above for tips on ...
# 3     home and garden  Who isn't going to want to kick up their heels...
# 4     home and garden  10 Unexpected Natural Cleaners Like ketchup......
# ...               ...                                                ...
# 2302  home and garden  These handy Kitchen Storage Solutions for Ever...
# 2303  home and garden  Why Zoe Saldana Is Cool Buying Her Sons' Cloth...
# 2304  home and garden  Watch Mister Rogers Defend Public Programming ...
# 2305  home and garden                   #TalkToMe Meet the Mildon Family
# 2306  home and garden                                   baat design -
#
# [2307 rows x 2 columns]

# %%
data_frames = [df_home_and_garden_augment, df_home_and_garden_augment_1, df_home_and_garden_augment_2]
df_final_home_and_garden_augment = pd.concat(data_frames, ignore_index=True)

# %%
df_final_home_and_garden_augment.to_csv('df_home_and_garden_augumented.csv', index=False)

# %%
df1=pd.read_csv("df_home_and_garden_augumented.csv")

# %%
df1.shape
# Out:
# (6921, 2)
