# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/TIL DATASET/train (10).csv")
df.head(10)
# Out:
#                                                 text                    target
# 0  Since she was a little girl, Tionna's on and o...      books and literature
# 1  TOURNAMENT: NorCal IN HAND BRACKET SERIES. DET...                    sports
# 2  Mark Salling committed suicide by hanging, acc...                television
# 3            This Beach Is Basically Heaven On Earth                    travel
# 4    Hasbro exec who helped create GI Joe dies at 86    arts and entertainment
# 5             Biggest Bird That Ever Flew Discovered  technology and computing
# 6  Works for Wrangler Bestop XXL Tire Cover It is...                automotive
# 7  Toyota To Settle Justice Department Probe Over...  technology and computing
# 8  Chevy Cruze sales halted for airbag issue, 330...  technology and computing
# 9            What Your Child's New Teacher Must Know           home and garden

# %%
df_food_and_drink = df[df['target'] == 'food and drink']
df_food_and_drink
# Out:
#                                                      text          target
# 255     Scotch enthusiasm is at an all-time high these...  food and drink
# 259     Disney parks have undergone culinary transform...  food and drink
# 327     If there were ever a cake for lemon lovers, it...  food and drink
# 428     kitchen stories recipes and desserts from greece   food and drink
# 534     erin kane Â– a japanese food blog with authent...  food and drink
# ...                                                   ...             ...
# 573932  I know you can whip this up in minutes because...  food and drink
# 573965  You won't miss the burgers for a second. The R...  food and drink
# 573974  OH NO! Theres A Whipped Cream Shortage Just B...  food and drink
# 574009  New Orleans, we'll come visit you soon, we pro...  food and drink
# 574035  Stuffed, topped, fried, and combined with baco...  food and drink
#
# [8542 rows x 2 columns]

# %%
num_rows = len(df_food_and_drink)
rows_per_df = num_rows // 3

dfs = []
for i in range(3):
    start_idx = i * rows_per_df
    end_idx = start_idx + rows_per_df
    if i == 3:
        end_idx = num_rows
    df_split = df_food_and_drink.iloc[start_idx:end_idx].copy()
    dfs.append(df_split)

df_names = ['df_food_and_drink_1', 'df_food_and_drink_2', 'df_food_and_drink_3']
for i, df_split in enumerate(dfs):
    globals()[df_names[i]] = df_split

# %%
df_food_and_drink_1
# Out:
#                                                      text          target
# 255     Scotch enthusiasm is at an all-time high these...  food and drink
# 259     Disney parks have undergone culinary transform...  food and drink
# 327     If there were ever a cake for lemon lovers, it...  food and drink
# 428     kitchen stories recipes and desserts from greece   food and drink
# 534     erin kane Â– a japanese food blog with authent...  food and drink
# ...                                                   ...             ...
# 190517  Pizza Hut is thinking out of the pizza box wit...  food and drink
# 190534  We had thirty minutes to cook and an audience ...  food and drink
# 190567   Chia Choc Chip Cookies That Will Change Your ...  food and drink
# 190690  One obligation that almost all mothers share i...  food and drink
# 190702  I will admit, I'm not the biggest nut person. ...  food and drink
#
# [2847 rows x 2 columns]

# %%
df_food_and_drink_2
# Out:
#                                                      text          target
# 190723       11 North African And Middle Eastern Desserts  food and drink
# 190840   18 All-Star Cookie Swap Recipes For The Holidays  food and drink
# 190880  Food critics eat Oreos! Gasp! Food Informants:...  food and drink
# 190942  If you think you make the best guacamole, we'r...  food and drink
# 191054  The Peachoid, which looms over I-85, is any re...  food and drink
# ...                                                   ...             ...
# 385261  reddirtcooking | oklahoma cooking with an atti...  food and drink
# 385294  1. If you purchase the baguette, you have earn...  food and drink
# 385397  terry's west village wines & spirits - terry's...  food and drink
# 385439  Because apparently some people are okay with s...  food and drink
# 385480  No matter how apt, wine remarks can become cli...  food and drink
#
# [2847 rows x 2 columns]

# %%
df_food_and_drink_3
# Out:
#                                                      text          target
# 385591     12 Of The Most Delicious Easter Brunch Recipes  food and drink
# 385768  Grilled Salad Is So Much Better Than It Sounds...  food and drink
# 385850  wine openers | notes on wine and the life that...  food and drink
# 385877  With the worry that American beef is pumped up...  food and drink
# 385942  beer brewing & wine making supplies | beer win...  food and drink
# ...                                                   ...             ...
# 573844  #1 online indian grocery shop in europe | most...  food and drink
# 573932  I know you can whip this up in minutes because...  food and drink
# 573965  You won't miss the burgers for a second. The R...  food and drink
# 573974  OH NO! Theres A Whipped Cream Shortage Just B...  food and drink
# 574009  New Orleans, we'll come visit you soon, we pro...  food and drink
#
# [2847 rows x 2 columns]

# %%
import random
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

def get_synonyms_nltk(word):
    synonyms = set()
    for syn in wordnet.synsets(word):
        for lemma in syn.lemmas():
            synonyms.add(lemma.name().replace("_", " "))
    if word in synonyms:
        synonyms.remove(word)
    return list(synonyms)

def synonym_replacement_nltk(text, n=1):
    stop_words = set(stopwords.words("english"))
    words = word_tokenize(text)
    words = [word.lower() for word in words if word.isalpha() and word.lower() not in stop_words]
    augmented_texts = []

    for _ in range(n):
        augmented_text = words.copy()
        for i in range(len(words)):
            if random.random() < 0.15:
                synonyms = get_synonyms_nltk(words[i])
                if synonyms:
                    augmented_text[i] = random.choice(synonyms)
        augmented_texts.append(' '.join(augmented_text))

    return augmented_texts

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
augmented_texts = []
for index, row in df_food_and_drink_1.iterrows():
    augmented_text = synonym_replacement_nltk(row['text'])
    augmented_texts.extend(augmented_text)

data_augment = {'category': ['food and drink'] * len(augmented_texts),
                'text': augmented_texts}

df_food_and_drink_augment = pd.DataFrame(data_augment)
df_food_and_drink_augment
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#             category                                               text
# 0     food and drink  scotch enthusiasm richly days good reason fasc...
# 1     food and drink  Disney parks undergone culinary transformation...
# 2     food and drink      ever cake lemon lovers daft sweets make swoon
# 3     food and drink              kitchen stories recipe desserts Ellas
# 4     food and drink  Erin kane japanese food blog authentic japanes...
# ...              ...                                                ...
# 2842  food and drink  pizza hut thinking pizza pie box one pizza hut...
# ...

# %%
# !pip install spacy
# !python -m spacy download en_core_web_lg
# Out:
# ...
# 2023-08-07 21:34:39.390605: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-07 21:34:41.824549: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 1.1 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
import spacy

# Load the 'en_core_web_lg' model
nlp = spacy.load('en_core_web_lg')

# Rest of your code using the 'nlp' object

# %%
def text_rotation_spacy(text, n=1):
    augmented_texts = []
    sentences = list(nlp(text).sents)
    for _ in range(n):
        random.shuffle(sentences)
        augmented_texts.append(' '.join([sent.text for sent in sentences]))
    return augmented_texts

augmented_texts = []
for index, row in df_food_and_drink_3.iterrows():
    augmented_text = text_rotation_spacy(row['text'])
    augmented_texts.extend(augmented_text)

data_augment = {'category': ['food and drink'] * len(augmented_texts),
                'text': augmented_texts}

df_food_and_drink_augment_2 = pd.DataFrame(data_augment)

df_food_and_drink_augment_2
# Out:
#             category                                               text
# 0     food and drink     12 Of The Most Delicious Easter Brunch Recipes
# 1     food and drink  Grilled Salad Is So Much Better Than It Sounds...
# 2     food and drink  wine openers | notes on wine and the life that...
# 3     food and drink  This Little Piggy Went To Market: Where Does Y...
# 4     food and drink  beer brewing & wine making supplies | beer win...
# ...              ...                                                ...
# 2842  food and drink  get grocery offers the largest variety of 3000...
# 2843  food and drink  Pesto in 10 Minutes After cutting the fresh ba...
# 2844  food and drink  The Recipes That'll Finally Make You Love Gril...
# 2845  food and drink  OH NO! Theres A Whipped Cream Shortage Just B...
# 2846  food and drink  New Orleans Food Video By Federico Fracchia Ne...
#
# [2847 rows x 2 columns]

# %%
def random_deletion_spacy(text, n=1, p=0.15):
    doc = nlp(text)
    augmented_texts = []
    for _ in range(n):
        augmented_text = [token.text for token in doc if random.random() > p]
        augmented_texts.append(' '.join(augmented_text))
    return augmented_texts

augmented_texts = []
for index, row in df_food_and_drink_2.iterrows():
    augmented_text = random_deletion_spacy(row['text'])
    augmented_texts.extend(augmented_text)

data_augment = {'category': ['food and drink'] * len(augmented_texts),
                'text': augmented_texts}

df_food_and_drink_augment_1 = pd.DataFrame(data_augment)
df_food_and_drink_augment_1
# Out:
#             category                                               text
# 0     food and drink           11 North African Middle Eastern Desserts
# 1     food and drink                      18 - Star Cookie Swap For The
# 2     food and drink  Food critics eat ! Gasp ! Food : A Week In The...
# 3     food and drink  If you you the best guacamole , we 're sorry t...
# 4     food and drink  The Peachoid which looms over I-85 is any repa...
# ...              ...                                                ...
# 2842  food and drink  reddirtcooking | oklahoma cooking an attitude ...
# 2843  food and drink  1 . If you purchase the baguette , you have ea...
# 2844  food and drink  terry west village wines & - west village wine...
# 2845  food and drink  Because apparently some people are with spendi...
# 2846  food and drink  how apt , wine remarks can become clichéd The ...
#
# [2847 rows x 2 columns]

# %%
data_frames = [df_food_and_drink_augment, df_food_and_drink_augment_1, df_food_and_drink_augment_2]
df_final_food_and_drink_augment = pd.concat(data_frames, ignore_index=True)

# %%
df_final_food_and_drink_augment.to_csv('df_food_and_drink_augumented.csv', index=False)

# %%
df1=pd.read_csv("df_food_and_drink_augumented.csv")

# %%
df1.shape
# Out:
# (8541, 2)
