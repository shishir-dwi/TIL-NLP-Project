# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import string 
import emoji
import re

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
from nltk.corpus import stopwords

# %%
df = pd.read_csv("sample_df.csv")
df
# Out:
#                                                      text              target  \
# 0       NEW DELHI: The Andhra Pradesh Public Service C...  academic interests
# 1       PUNE: Two weeks after the new academic year ha...  academic interests
# 2       GUWAHATI: The results of the CBSE Class X exam...  academic interests
# 3       admission into the IIMs," said Kapoor. Across ...  academic interests
# 4       Mangaluru: The Mangalore Institute of Technolo...  academic interests
# ...                                                   ...                 ...
# 519995  NAGPUR: Akshay Zadgaonkar is a child prodigy. ...        video gaming
# 519996  \nBayonetta lead Hideki Kamiya reckons the lat...        video gaming
# 519997  \nAl Pacino thinks the original Godfather is b...        video gaming
# 519998  The latest episode of Imlie begins with Aryan ...        video gaming
# 519999  While the entire world is under lockdown in va...        video gaming
#
#         Word Count
# 0              239
# 1              500
# 2              470
# 3              108
# 4              336
# ...            ...
# 519995         500
# 519996         290
# 519997         259
# 519998         251
# 519999         238
#
# [520000 rows x 3 columns]

# %%
print(len(pd.unique(df.target)))
# Out:
# 26

# %%
pd.unique(df.target)
# Out:
# array(['academic interests', 'arts and culture', 'automotives',
#        'books and literature', 'business and finance', 'careers',
#        'family and relationships', 'food and drinks', 'health',
#        'healthy living', 'hobbies and interests', 'home and garden',
#        'movies', 'music and audio', 'news and politics',
#        'personal finance', 'pets',
#        'pharmaceuticals, conditions, and symptoms', 'real estate',
#        'shopping', 'sports', 'style and fashion',
#        'technology and computing', 'television', 'travel', 'video gaming'],
#       dtype=object)

# %% [markdown]
# ### Lowercase the dataset

# %%
df.text = df.text.str.lower()
df.text = df.text.astype(str)
df.dtypes
# Out:
# text          object
# target        object
# Word Count     int64
# dtype: object

# %% [markdown]
# ### Removing Punctuations

# %%
# Removing punctuations using string module

def remove_punct(text):
    if isinstance(text, str):
        return text.translate(str.maketrans("", "", string.punctuation))
    elif pd.notna(text):
        return str(text)
    else:
        return text

df['text'] = df['text'].apply(remove_punct)
df

# Removing punctuations using regex 

# import re
# res = ''
# for i in ex:
#     word = re.sub(r'([^\w\s]|_)', '', i)
#     res += word
# res
# Out:
#                                                      text              target  \
# 0       new delhi the andhra pradesh public service co...  academic interests
# 1       pune two weeks after the new academic year has...  academic interests
# 2       guwahati the results of the cbse class x exams...  academic interests
# 3       admission into the iims said kapoor across 13 ...  academic interests
# 4       mangaluru the mangalore institute of technolog...  academic interests
# ...                                                   ...                 ...
# 519995  nagpur akshay zadgaonkar is a child prodigy hi...        video gaming
# 519996  \nbayonetta lead hideki kamiya reckons the lat...        video gaming
# 519997  \nal pacino thinks the original godfather is b...        video gaming
# 519998  the latest episode of imlie begins with aryan ...        video gaming
# 519999  while the entire world is under lockdown in va...        video gaming
#
#         Word Count
# 0              239
# 1              500
# 2              470
# 3              108
# 4              336
# ...            ...
# 519995         500
# 519996         290
# 519997         259
# 519998         251
# 519999         238
#
# [520000 rows x 3 columns]

# %% [markdown]
# ### Removing URLs and Emojis

# %%
def removeURLandEmoji(text):
    text = re.sub(r"http\S+|www\S+|https\S+", "", text, flags=re.MULTILINE)
    text = emoji.demojize(text)
    text = re.sub(r":[^:]+:", "", text)
    
    return text
    
df.text = df.text.apply(removeURLandEmoji)
df
# Out:
#                                                      text              target  \
# 0       new delhi the andhra pradesh public service co...  academic interests
# 1       pune two weeks after the new academic year has...  academic interests
# 2       guwahati the results of the cbse class x exams...  academic interests
# 3       admission into the iims said kapoor across 13 ...  academic interests
# 4       mangaluru the mangalore institute of technolog...  academic interests
# ...                                                   ...                 ...
# 519995  nagpur akshay zadgaonkar is a child prodigy hi...        video gaming
# 519996  \nbayonetta lead hideki kamiya reckons the lat...        video gaming
# 519997  \nal pacino thinks the original godfather is b...        video gaming
# 519998  the latest episode of imlie begins with aryan ...        video gaming
# 519999  while the entire world is under lockdown in va...        video gaming
#
#         Word Count
# 0              239
# 1              500
# 2              470
# 3              108
# 4              336
# ...            ...
# 519995         500
# 519996         290
# 519997         259
# 519998         251
# 519999         238
#
# [520000 rows x 3 columns]

# %%
def remove_Emails_and_Numbers(text):
    email_pattern = r'\S+@\S+\.\S+'
    number_pattern = r'\b\d+\b'

    cleaned_text = re.sub(email_pattern, '', text)
    cleaned_text = re.sub(number_pattern, '', cleaned_text)
    return cleaned_text

df.text = df.text.apply(remove_Emails_and_Numbers)
df
# Out:
#                                                      text              target  \
# 0       new delhi the andhra pradesh public service co...  academic interests
# 1       pune two weeks after the new academic year has...  academic interests
# 2       guwahati the results of the cbse class x exams...  academic interests
# 3       admission into the iims said kapoor across  ii...  academic interests
# 4       mangaluru the mangalore institute of technolog...  academic interests
# ...                                                   ...                 ...
# 519995  nagpur akshay zadgaonkar is a child prodigy hi...        video gaming
# 519996  \nbayonetta lead hideki kamiya reckons the lat...        video gaming
# 519997  \nal pacino thinks the original godfather is b...        video gaming
# 519998  the latest episode of imlie begins with aryan ...        video gaming
# 519999  while the entire world is under lockdown in va...        video gaming
#
#         Word Count
# 0              239
# 1              500
# 2              470
# 3              108
# 4              336
# ...            ...
# 519995         500
# 519996         290
# 519997         259
# 519998         251
# 519999         238
#
# [520000 rows x 3 columns]

# %%
import codecs

def removeSpecialChar(text):
    pattern = r'[^a-zA-Z\s]'

    cleaned_text = re.sub(pattern, '', text)
    cleaned_text = cleaned_text.replace('\n', ' ') # remove '\n' with ' '
    cleaned_text = codecs.decode(cleaned_text, 'unicode_escape') # remove '\' with ''
    cleaned_text = cleaned_text.replace('\xa0', ' ') # remove '\xa0' with ' '
    return cleaned_text

df.text = df.text.apply(removeSpecialChar)
df
# Out:
#                                                      text              target  \
# 0       new delhi the andhra pradesh public service co...  academic interests
# 1       pune two weeks after the new academic year has...  academic interests
# 2       guwahati the results of the cbse class x exams...  academic interests
# 3       admission into the iims said kapoor across  ii...  academic interests
# 4       mangaluru the mangalore institute of technolog...  academic interests
# ...                                                   ...                 ...
# 519995  nagpur akshay zadgaonkar is a child prodigy hi...        video gaming
# 519996   bayonetta lead hideki kamiya reckons the late...        video gaming
# 519997   al pacino thinks the original godfather is be...        video gaming
# 519998  the latest episode of imlie begins with aryan ...        video gaming
# 519999  while the entire world is under lockdown in va...        video gaming
#
#         Word Count
# 0              239
# 1              500
# 2              470
# 3              108
# 4              336
# ...            ...
# 519995         500
# 519996         290
# 519997         259
# 519998         251
# 519999         238
#
# [520000 rows x 3 columns]

# %%
def has_html_elements(text):
    try:
        soup = BeautifulSoup(text, 'html.parser')
        return len(soup.find_all()) > 0
    except:
        return True

df['has_html'] = df['text'].apply(has_html_elements)
df = df[~df['has_html']]
df = df.drop('has_html', axis = 1)
df
# Out:
#                                                      text              target  \
# 0       new delhi the andhra pradesh public service co...  academic interests
# 1       pune two weeks after the new academic year has...  academic interests
# 2       guwahati the results of the cbse class x exams...  academic interests
# 3       admission into the iims said kapoor across  ii...  academic interests
# 4       mangaluru the mangalore institute of technolog...  academic interests
# ...                                                   ...                 ...
# 519995  nagpur akshay zadgaonkar is a child prodigy hi...        video gaming
# 519996   bayonetta lead hideki kamiya reckons the late...        video gaming
# 519997   al pacino thinks the original godfather is be...        video gaming
# 519998  the latest episode of imlie begins with aryan ...        video gaming
# 519999  while the entire world is under lockdown in va...        video gaming
#
#         Word Count
# 0              239
# 1              500
# 2              470
# 3              108
# 4              336
# ...            ...
# 519995         500
# 519996         290
# 519997         259
# 519998         251
# 519999         238
#
# [520000 rows x 3 columns]

# %% [markdown]
# ### Tokenization

# %%
def tokens(text):
    return word_tokenize(text)

df['tokens'] = df['text'].apply(tokens)
df
# Out:
#                                                      text              target  \
# 0       new delhi the andhra pradesh public service co...  academic interests
# 1       pune two weeks after the new academic year has...  academic interests
# 2       guwahati the results of the cbse class x exams...  academic interests
# 3       admission into the iims said kapoor across  ii...  academic interests
# 4       mangaluru the mangalore institute of technolog...  academic interests
# ...                                                   ...                 ...
# 519995  nagpur akshay zadgaonkar is a child prodigy hi...        video gaming
# 519996   bayonetta lead hideki kamiya reckons the late...        video gaming
# 519997   al pacino thinks the original godfather is be...        video gaming
# 519998  the latest episode of imlie begins with aryan ...        video gaming
# 519999  while the entire world is under lockdown in va...        video gaming
#
#         Word Count                                             tokens
# 0              239  [new, delhi, the, andhra, pradesh, public, ser...
# 1              500  [pune, two, weeks, after, the, new, academic, ...
# 2              470  [guwahati, the, results, of, the, cbse, class,...
# 3              108  [admission, into, the, iims, said, kapoor, acr...
# 4              336  [mangaluru, the, mangalore, institute, of, tec...
# ...            ...                                                ...
# 519995         500  [nagpur, akshay, zadgaonkar, is, a, child, pro...
# 519996         290  [bayonetta, lead, hideki, kamiya, reckons, the...
# 519997         259  [al, pacino, thinks, the, original, godfather,...
# 519998         251  [the, latest, episode, of, imlie, begins, with...
# 519999         238  [while, the, entire, world, is, under, lockdow...
#
# [520000 rows x 4 columns]

# %% [markdown]
# ### Removing stopwords

# %%
# removing stopwords

stops = set(stopwords.words('english'))

def remove_stopwords(tokens):
    return [token for token in tokens if token.lower() not in stops]

df['tokens'] = df['tokens'].apply(remove_stopwords)
df
# Out:
#                                                      text              target  \
# 0       new delhi the andhra pradesh public service co...  academic interests
# 1       pune two weeks after the new academic year has...  academic interests
# 2       guwahati the results of the cbse class x exams...  academic interests
# 3       admission into the iims said kapoor across  ii...  academic interests
# 4       mangaluru the mangalore institute of technolog...  academic interests
# ...                                                   ...                 ...
# 519995  nagpur akshay zadgaonkar is a child prodigy hi...        video gaming
# 519996   bayonetta lead hideki kamiya reckons the late...        video gaming
# 519997   al pacino thinks the original godfather is be...        video gaming
# 519998  the latest episode of imlie begins with aryan ...        video gaming
# 519999  while the entire world is under lockdown in va...        video gaming
#
#         Word Count                                             tokens
# 0              239  [new, delhi, andhra, pradesh, public, service,...
# 1              500  [pune, two, weeks, new, academic, year, begun,...
# 2              470  [guwahati, results, cbse, class, x, exams, ann...
# 3              108  [admission, iims, said, kapoor, across, iims, ...
# 4              336  [mangaluru, mangalore, institute, technology, ...
# ...            ...                                                ...
# 519995         500  [nagpur, akshay, zadgaonkar, child, prodigy, c...
# 519996         290  [bayonetta, lead, hideki, kamiya, reckons, lat...
# 519997         259  [al, pacino, thinks, original, godfather, bett...
# 519998         251  [latest, episode, imlie, begins, aryan, receiv...
# 519999         238  [entire, world, lockdown, various, degrees, pe...
#
# [520000 rows x 4 columns]

# %%
df = df.drop(columns = ['text', 'Word Count'])
df
# Out:
#                     target                                             tokens
# 0       academic interests  [new, delhi, andhra, pradesh, public, service,...
# 1       academic interests  [pune, two, weeks, new, academic, year, begun,...
# 2       academic interests  [guwahati, results, cbse, class, x, exams, ann...
# 3       academic interests  [admission, iims, said, kapoor, across, iims, ...
# 4       academic interests  [mangaluru, mangalore, institute, technology, ...
# ...                    ...                                                ...
# 519995        video gaming  [nagpur, akshay, zadgaonkar, child, prodigy, c...
# 519996        video gaming  [bayonetta, lead, hideki, kamiya, reckons, lat...
# 519997        video gaming  [al, pacino, thinks, original, godfather, bett...
# 519998        video gaming  [latest, episode, imlie, begins, aryan, receiv...
# 519999        video gaming  [entire, world, lockdown, various, degrees, pe...
#
# [520000 rows x 2 columns]

# %% [markdown]
# ### Lemmatization

# %%
# WORDNET LEMMATIZER (with appropriate pos tags)

# nltk.download('averaged_perceptron_tagger')

lemmatizer = WordNetLemmatizer()

def pos_tagger(nltk_tag):
    if nltk_tag.startswith('J'):
        return wordnet.ADJ
    elif nltk_tag.startswith('V'):
        return wordnet.VERB
    elif nltk_tag.startswith('N'):
        return wordnet.NOUN
    elif nltk_tag.startswith('R'):
        return wordnet.ADV
    else:
        return None

def lemmatize_text(tokens):
    pos_tagged = nltk.pos_tag(tokens)
    wordnet_tagged = [(word, pos_tagger(tag)) for word, tag in pos_tagged]
    lemmatized = []
    for word, tag in wordnet_tagged:
        if tag is None:
            lemmatized.append(word)
        else:
            lemmatized.append(lemmatizer.lemmatize(word, tag))
    return lemmatized

df['tokens'] = df['tokens'].apply(lemmatize_text)
df
# Out:
#                     target                                             tokens
# 0       academic interests  [new, delhi, andhra, pradesh, public, service,...
# 1       academic interests  [pune, two, week, new, academic, year, begin, ...
# 2       academic interests  [guwahati, result, cbse, class, x, exam, annou...
# 3       academic interests  [admission, iims, say, kapoor, across, iims, s...
# 4       academic interests  [mangaluru, mangalore, institute, technology, ...
# ...                    ...                                                ...
# 519995        video gaming  [nagpur, akshay, zadgaonkar, child, prodigy, c...
# 519996        video gaming  [bayonetta, lead, hideki, kamiya, reckons, lat...
# 519997        video gaming  [al, pacino, think, original, godfather, well,...
# 519998        video gaming  [late, episode, imlie, begin, aryan, receive, ...
# 519999        video gaming  [entire, world, lockdown, various, degree, peo...
#
# [520000 rows x 2 columns]

# %%
df['tokens'] = df['tokens'].apply(tuple)
df.drop_duplicates(subset=['tokens'], ignore_index=True, inplace=True)
df
# Out:
#                     target                                             tokens
# 0       academic interests  (new, delhi, andhra, pradesh, public, service,...
# 1       academic interests  (pune, two, week, new, academic, year, begin, ...
# 2       academic interests  (guwahati, result, cbse, class, x, exam, annou...
# 3       academic interests  (admission, iims, say, kapoor, across, iims, s...
# 4       academic interests  (mangaluru, mangalore, institute, technology, ...
# ...                    ...                                                ...
# 518330        video gaming  (nagpur, akshay, zadgaonkar, child, prodigy, c...
# 518331        video gaming  (bayonetta, lead, hideki, kamiya, reckons, lat...
# 518332        video gaming  (al, pacino, think, original, godfather, well,...
# 518333        video gaming  (late, episode, imlie, begin, aryan, receive, ...
# 518334        video gaming  (entire, world, lockdown, various, degree, peo...
#
# [518335 rows x 2 columns]

# %%
 df.target.value_counts()
# Out:
# pharmaceuticals, conditions, and symptoms    20000
# academic interests                           19993
# movies                                       19985
# healthy living                               19984
# television                                   19980
# family and relationships                     19975
# style and fashion                            19973
# news and politics                            19973
# automotives                                  19965
# sports                                       19964
# music and audio                              19961
# video gaming                                 19957
# arts and culture                             19947
# pets                                         19944
# food and drinks                              19942
# hobbies and interests                        19939
# travel                                       19930
# shopping                                     19929
# home and garden                              19928
# health                                       19927
# business and finance                         19923
# real estate                                  19913
# personal finance                             19890
# technology and computing                     19873
# careers                                      19777
# books and literature                         19763
# Name: target, dtype: int64

# %%
df.to_csv('preprocessed_df.csv', index = False)
