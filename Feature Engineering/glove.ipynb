# %% [markdown]
# ## **Importing Libraries**

# %%
import numpy as np
import pandas as pd
import ast
import torch
from torchtext.vocab import GloVe
from torchtext.data.utils import get_tokenizer

# %% [markdown]
# ## **Load preprocessed Dataset**

# %%
preprocessed_df = pd.read_csv('/content/drive/MyDrive/TIL/preprocessed_df.zip')
preprocessed_df
# Out:
#                     target                                             tokens
# 0       academic interests  ('new', 'delhi', 'andhra', 'pradesh', 'public'...
# 1       academic interests  ('pune', 'two', 'week', 'new', 'academic', 'ye...
# 2       academic interests  ('guwahati', 'result', 'cbse', 'class', 'x', '...
# 3       academic interests  ('admission', 'iims', 'say', 'kapoor', 'across...
# 4       academic interests  ('mangaluru', 'mangalore', 'institute', 'techn...
# ...                    ...                                                ...
# 518330        video gaming  ('nagpur', 'akshay', 'zadgaonkar', 'child', 'p...
# 518331        video gaming  ('bayonetta', 'lead', 'hideki', 'kamiya', 'rec...
# 518332        video gaming  ('al', 'pacino', 'think', 'original', 'godfath...
# 518333        video gaming  ('late', 'episode', 'imlie', 'begin', 'aryan',...
# 518334        video gaming  ('entire', 'world', 'lockdown', 'various', 'de...
#
# [518335 rows x 2 columns]

# %% [markdown]
# ## **Convert the tokens column from string representations to Python lists**

# %%
preprocessed_df.tokens = preprocessed_df.tokens.apply(ast.literal_eval)
preprocessed_df
# Out:
#                     target                                             tokens
# 0       academic interests  (new, delhi, andhra, pradesh, public, service,...
# 1       academic interests  (pune, two, week, new, academic, year, begin, ...
# 2       academic interests  (guwahati, result, cbse, class, x, exam, annou...
# 3       academic interests  (admission, iims, say, kapoor, across, iims, s...
# 4       academic interests  (mangaluru, mangalore, institute, technology, ...
# ...                    ...                                                ...
# 518330        video gaming  (nagpur, akshay, zadgaonkar, child, prodigy, c...
# 518331        video gaming  (bayonetta, lead, hideki, kamiya, reckons, lat...
# 518332        video gaming  (al, pacino, think, original, godfather, well,...
# 518333        video gaming  (late, episode, imlie, begin, aryan, receive, ...
# 518334        video gaming  (entire, world, lockdown, various, degree, peo...
#
# [518335 rows x 2 columns]

# %% [markdown]
# ## **26 IAB CATEGORIES**

# %%
preprocessed_df['target'].unique()
# Out:
# array(['academic interests', 'arts and culture', 'automotives',
#        'books and literature', 'business and finance', 'careers',
#        'family and relationships', 'food and drinks', 'health',
#        'healthy living', 'hobbies and interests', 'home and garden',
#        'movies', 'music and audio', 'news and politics',
#        'personal finance', 'pets',
#        'pharmaceuticals, conditions, and symptoms', 'real estate',
#        'shopping', 'sports', 'style and fashion',
#        'technology and computing', 'television', 'travel', 'video gaming'],
#       dtype=object)

# %% [markdown]
# ## **Glove Model**

# %%
# Load GloVe embeddings
glove=GloVe(name='6B',dim=200)

# %% [markdown]
# ## **Save the Model Using Joblib**

# %%
# !pip install joblib
import joblib as jb
jb.dump(glove, '/content/drive/MyDrive/TIL/golve_model.joblib')
# Out:
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (1.3.2)
# ['/content/drive/MyDrive/TIL/golve_model.joblib']

# %% [markdown]
# ## **Load The Glove Model**

# %%
glove = jb.load('/content/drive/MyDrive/TIL/golve_model.joblib')

# %% [markdown]
# ## **generate_glove_embeddings function**

# %%
import torch
import numpy as np
#glove = jb.load('golve model.joblib')
#glove = GloVe(name='6B', dim=100)

# Function to generate GloVe embeddings
def generate_glove_embeddings(tokens):
    embeddings = [glove[token] for token in tokens]
    embeddings_tensor = torch.stack(embeddings)
    embeddings_tensor=np.mean(embeddings_tensor.numpy(),axis=1)
    return embeddings_tensor

# %% [markdown]
# Calculate and store the count of tokens in each row

# %%
preprocessed_df['Count'] = preprocessed_df.tokens.apply(len)
preprocessed_df
# Out:
#                     target                                             tokens  \
# 0       academic interests  (new, delhi, andhra, pradesh, public, service,...
# 1       academic interests  (pune, two, week, new, academic, year, begin, ...
# 2       academic interests  (guwahati, result, cbse, class, x, exam, annou...
# 3       academic interests  (admission, iims, say, kapoor, across, iims, s...
# 4       academic interests  (mangaluru, mangalore, institute, technology, ...
# ...                    ...                                                ...
# 518330        video gaming  (nagpur, akshay, zadgaonkar, child, prodigy, c...
# 518331        video gaming  (bayonetta, lead, hideki, kamiya, reckons, lat...
# 518332        video gaming  (al, pacino, think, original, godfather, well,...
# 518333        video gaming  (late, episode, imlie, begin, aryan, receive, ...
# 518334        video gaming  (entire, world, lockdown, various, degree, peo...
#
#         Count
# 0         151
# 1         269
# 2         261
# 3          56
# 4         203
# ...       ...
# 518330    291
# 518331    176
# 518332    147
# 518333    130
# 518334    115
#
# [518335 rows x 3 columns]

# %% [markdown]
# Filter the preprocessed DataFrame to keep only rows with a Count value greater than or equal to 50

# %%
preprocessed_df=preprocessed_df[preprocessed_df.Count >=50]
preprocessed_df
# Out:
#                     target                                             tokens  \
# 0       academic interests  (new, delhi, andhra, pradesh, public, service,...
# 1       academic interests  (pune, two, week, new, academic, year, begin, ...
# 2       academic interests  (guwahati, result, cbse, class, x, exam, annou...
# 3       academic interests  (admission, iims, say, kapoor, across, iims, s...
# 4       academic interests  (mangaluru, mangalore, institute, technology, ...
# ...                    ...                                                ...
# 518330        video gaming  (nagpur, akshay, zadgaonkar, child, prodigy, c...
# 518331        video gaming  (bayonetta, lead, hideki, kamiya, reckons, lat...
# 518332        video gaming  (al, pacino, think, original, godfather, well,...
# 518333        video gaming  (late, episode, imlie, begin, aryan, receive, ...
# 518334        video gaming  (entire, world, lockdown, various, degree, peo...
#
#         Count
# 0         151
# 1         269
# 2         261
# 3          56
# 4         203
# ...       ...
# 518330    291
# 518331    176
# 518332    147
# 518333    130
# 518334    115
#
# [517498 rows x 3 columns]

# %%
preprocessed_df.drop(columns=['Count'], inplace=True)
preprocessed_df
# Out:
# <ipython-input-11-0257f26970c5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   preprocessed_df.drop(columns=['Count'], inplace=True)
#                     target                                             tokens
# 0       academic interests  (new, delhi, andhra, pradesh, public, service,...
# 1       academic interests  (pune, two, week, new, academic, year, begin, ...
# 2       academic interests  (guwahati, result, cbse, class, x, exam, annou...
# 3       academic interests  (admission, iims, say, kapoor, across, iims, s...
# 4       academic interests  (mangaluru, mangalore, institute, technology, ...
# ...                    ...                                                ...
# 518330        video gaming  (nagpur, akshay, zadgaonkar, child, prodigy, c...
# 518331        video gaming  (bayonetta, lead, hideki, kamiya, reckons, lat...
# 518332        video gaming  (al, pacino, think, original, godfather, well,...
# 518333        video gaming  (late, episode, imlie, begin, aryan, receive, ...
# 518334        video gaming  (entire, world, lockdown, various, degree, peo...
#
# [517498 rows x 2 columns]

# %% [markdown]
# ## **Define a function to create category dataframes**

# %%
def category_dataframes(preprocessed_df):
    unique_categories = preprocessed_df['target'].unique()
    category_dataframes = {}

    for category in unique_categories:
        filtered_df = preprocessed_df[preprocessed_df['target'] == category].copy()
        filtered_df.reset_index(drop=True, inplace=True)
        category_dataframes[category] = filtered_df
    return category_dataframes

# %% [markdown]
# ## **Get category dataframes**

# %%
category_dfs = category_dataframes(preprocessed_df)

# %% [markdown]
# ## **Academic Interests**

# %%
category_dfs['academic interests']
embedding1 = category_dfs['academic interests'].tokens.apply(generate_glove_embeddings)
em = pd.DataFrame(embedding1)
em.rename(columns = {'tokens':'embeddings'}, inplace = True)
embedding = category_dfs['academic interests'].copy()
embedding
final_df1 = pd.concat([em, embedding], axis = 1)
final_df1
# Out:
#                                               embeddings              target  \
# 0      [-0.06352922, 0.001389485, 0.093901254, 0.1092...  academic interests
# 1      [0.027382972, 0.020358846, -0.063034385, -0.06...  academic interests
# 2      [0.016307771, -0.057271723, -0.07627775, -0.03...  academic interests
# 3      [0.008284974, -0.0022982287, -0.08882646, 0.07...  academic interests
# 4      [0.0, 0.051746417, -0.035366558, -0.021043224,...  academic interests
# ...                                                  ...                 ...
# 19979  [0.013106747, -0.009391723, -0.057271723, -0.0...  academic interests
# 19980  [-0.059588894, -0.057428002, -0.041993886, 0.0...  academic interests
# 19981  [0.027382972, -0.021834278, -0.03161209, -0.01...  academic interests
# 19982  [-0.06352922, 0.001389485, -0.016731532, 0.020...  academic interests
# 19983  [0.010947246, -0.021801576, -0.00022430137, 0....  academic interests
#
#                                                   tokens
# 0      (new, delhi, andhra, pradesh, public, service,...
# 1      (pune, two, week, new, academic, year, begin, ...
# 2      (guwahati, result, cbse, class, x, exam, annou...
# 3      (admission, iims, say, kapoor, across, iims, s...
# 4      (mangaluru, mangalore, institute, technology, ...
# ...                                                  ...
# 19979  (odisha, th, result, board, secondary, educati...
# 19980  (fund, federal, government, programme, urge, b...
# 19981  (pune, student, appear, secondary, school, cer...
# 19982  (new, delhi, past, two, day, see, surge, onlin...
# 19983  (telangana, state, public, service, commission...
#
# [19984 rows x 3 columns]

# %%
final_df1.embeddings.iloc[1].shape
# Out:
# (269,)

# %%
print(final_df1.embeddings.iloc[1])
# Out:
# [ 0.02738297  0.02035885 -0.06303439 -0.06352922 -0.05823029 -0.05605913
#  -0.07062508  0.0587532  -0.08236111 -0.02183428 -0.05159032  0.00243444
#   0.07144253  0.0084388   0.07432721 -0.07898504  0.01385185 -0.0796576
#   0.06786099 -0.06644168 -0.01161659  0.05743524  0.02738297  0.01952537
#  -0.07898504 -0.07167516  0.06786099 -0.03867244  0.03625012 -0.074986
#   0.03330103 -0.03536656 -0.06112597 -0.03986193  0.02797004 -0.08882646
#   0.09384246 -0.07898504  0.01952537 -0.02319264 -0.04185401  0.02738297
#  -0.07898504  0.00828497 -0.08236111 -0.10614736 -0.07167516 -0.01805367
#  -0.00282266 -0.07898504  0.02738297  0.01952537 -0.0972591  -0.02188545
#   0.09384246 -0.02183428 -0.06644168 -0.00416452  0.01388022 -0.03194802
#  -0.05079876  0.0137391   0.0587532  -0.02319264 -0.00416452  0.
#  -0.06096484 -0.00746276 -0.04450922  0.06786099  0.00828497  0.01952537
#  -0.05823029 -0.05605913  0.02738297 -0.00219455  0.051827   -0.04185401
#   0.00828497  0.         -0.03895469  0.0911735   0.          0.0587532
#  -0.01161659  0.05743524 -0.06096484 -0.00746276 -0.04450922  0.00828497
#  -0.06806125 -0.04283281 -0.04319064 -0.00416452  0.0587532  -0.02319264
#   0.02738297 -0.07167516 -0.00282266  0.02035885 -0.07520504 -0.05278541
#   0.00828497 -0.04502124  0.0587532  -0.00884506  0.01471554 -0.02183428
#  -0.04474772  0.08206188 -0.00884506 -0.07782872  0.02423722 -0.07898504
#  -0.05727172 -0.07970604 -0.09167207  0.00113948 -0.0535939   0.01425708
#  -0.07171944  0.00828497  0.02423722 -0.07898504 -0.03709297  0.02076215
#  -0.0417292   0.         -0.00633662 -0.00983837 -0.03914411  0.03625012
#  -0.04744614 -0.10715123  0.08984791 -0.01208871 -0.07520504 -0.03893806
#   0.03877699 -0.03853655 -0.02262401 -0.07898504 -0.02389359 -0.06029938
#  -0.01560235 -0.04911022 -0.08277592 -0.05233802 -0.07536586  0.00828497
#  -0.04319064 -0.02593426 -0.02188545  0.01425708 -0.01511082  0.01915518
#  -0.00633662 -0.08237288 -0.07520504 -0.05122384  0.00828497 -0.10615345
#  -0.05278541  0.051827    0.01060962 -0.0692184  -0.07171944 -0.07898504
#  -0.00416452 -0.07898504  0.          0.07144253  0.02738297 -0.01154331
#  -0.00980491  0.02538691  0.01264712 -0.09284669 -0.07898504 -0.00048511
#  -0.05218732 -0.08882646 -0.0431548  -0.04144043  0.01854723  0.00828497
#  -0.05605913 -0.05177181  0.00451924 -0.04404972 -0.04199389 -0.11658833
#  -0.06644168 -0.02180158 -0.01805367 -0.0972591  -0.02149929 -0.08277592
#  -0.02188545 -0.02183428 -0.00746276 -0.05605913 -0.00684681 -0.02183428
#  -0.08052316  0.00828497 -0.0990795  -0.05605913 -0.02183428 -0.02180158
#  -0.08052316  0.00828497  0.06786099  0.01845548 -0.05605913 -0.035988
#  -0.06644168 -0.01805367 -0.03887365  0.00828497 -0.02180158 -0.06440703
#   0.00828497 -0.01404495 -0.07898504 -0.02539606 -0.08277592 -0.04199389
#  -0.04327029 -0.03893806 -0.07898504 -0.08766773 -0.05605913 -0.01404495
#   0.00828497 -0.08237288  0.         -0.05420183  0.          0.05348753
#   0.01028223  0.          0.05619441  0.         -0.08882646  0.01764769
#   0.003453    0.03877699 -0.08369354 -0.07898504 -0.04865531  0.00828497
#  -0.00416452 -0.02593426 -0.02188545 -0.02183428  0.          0.05619441
#  -0.0977615  -0.03880859  0.02076215  0.00828497  0.06786099  0.01425708
#  -0.02635792 -0.07898504  0.02738297 -0.07183926  0.        ]

# %%
final_df1.embeddings.shape
# Out:
# (19984,)

# %%
# Print the embeddings for the first row
print(final_df1.embeddings)
# Out:
# 0        [-0.06352922, 0.001389485, 0.093901254, 0.1092...
# 1        [0.027382972, 0.020358846, -0.063034385, -0.06...
# 2        [0.016307771, -0.057271723, -0.07627775, -0.03...
# 3        [0.008284974, -0.0022982287, -0.08882646, 0.07...
# 4        [0.0, 0.051746417, -0.035366558, -0.021043224,...
#                                ...
# 19979    [0.013106747, -0.009391723, -0.057271723, -0.0...
# 19980    [-0.059588894, -0.057428002, -0.041993886, 0.0...
# 19981    [0.027382972, -0.021834278, -0.03161209, -0.01...
# 19982    [-0.06352922, 0.001389485, -0.016731532, 0.020...
# 19983    [0.010947246, -0.021801576, -0.00022430137, 0....
# Name: embeddings, Length: 19984, dtype: object

# %%
final_df1.embeddings.iloc[1].shape
# Out:
# (269,)

# %%
final_df1.to_csv("/content/drive/MyDrive/TIL/Word_Embeddings/academic_interests_.csv")

# %% [markdown]
# ## **Read The File**

# %%
dff=pd.read_csv("/content/drive/MyDrive/TIL/Word_Embeddings/academic_interests_.csv")
dff
# Out:
#        Unnamed: 0                                         embeddings  \
# 0               0  [-0.06352922  0.00138948  0.09390125  0.109289...
# 1               1  [ 0.02738297  0.02035885 -0.06303439 -0.063529...
# 2               2  [ 1.63077712e-02 -5.72717227e-02 -7.62777478e-...
# 3               3  [ 8.2849739e-03 -2.2982287e-03 -8.8826463e-02 ...
# 4               4  [ 0.          0.05174642 -0.03536656 -0.021043...
# ...           ...                                                ...
# 19979       19979  [ 0.01310675 -0.00939172 -0.05727172 -0.079574...
# 19980       19980  [-0.05958889 -0.057428   -0.04199389  0.006478...
# 19981       19981  [ 0.02738297 -0.02183428 -0.03161209 -0.011474...
# 19982       19982  [-0.06352922  0.00138948 -0.01673153  0.020358...
# 19983       19983  [ 0.01094725 -0.02180158 -0.0002243   0.034207...
#
#                    target                                             tokens
# 0      academic interests  ('new', 'delhi', 'andhra', 'pradesh', 'public'...
# 1      academic interests  ('pune', 'two', 'week', 'new', 'academic', 'ye...
# 2      academic interests  ('guwahati', 'result', 'cbse', 'class', 'x', '...
# 3      academic interests  ('admission', 'iims', 'say', 'kapoor', 'across...
# 4      academic interests  ('mangaluru', 'mangalore', 'institute', 'techn...
# ...                   ...                                                ...
# 19979  academic interests  ('odisha', 'th', 'result', 'board', 'secondary...
# 19980  academic interests  ('fund', 'federal', 'government', 'programme',...
# 19981  academic interests  ('pune', 'student', 'appear', 'secondary', 'sc...
# 19982  academic interests  ('new', 'delhi', 'past', 'two', 'day', 'see', ...
# 19983  academic interests  ('telangana', 'state', 'public', 'service', 'c...
#
# [19984 rows x 4 columns]

# %%
def convert_embeddings(embeddings):
  embeddings=embeddings.strip("[]")
  return np.array([float(value) for value in embeddings.split()])
dff["embeddings"]=dff["embeddings"].apply(convert_embeddings)

# %%
dff.embeddings.iloc[1].shape
# Out:
# (269,)

# %%
print(final_df1.embeddings.iloc[1])
# Out:
# [ 0.02738297  0.02035885 -0.06303439 -0.06352922 -0.05823029 -0.05605913
#  -0.07062508  0.0587532  -0.08236111 -0.02183428 -0.05159032  0.00243444
#   0.07144253  0.0084388   0.07432721 -0.07898504  0.01385185 -0.0796576
#   0.06786099 -0.06644168 -0.01161659  0.05743524  0.02738297  0.01952537
#  -0.07898504 -0.07167516  0.06786099 -0.03867244  0.03625012 -0.074986
#   0.03330103 -0.03536656 -0.06112597 -0.03986193  0.02797004 -0.08882646
#   0.09384246 -0.07898504  0.01952537 -0.02319264 -0.04185401  0.02738297
#  -0.07898504  0.00828497 -0.08236111 -0.10614736 -0.07167516 -0.01805367
#  -0.00282266 -0.07898504  0.02738297  0.01952537 -0.0972591  -0.02188545
#   0.09384246 -0.02183428 -0.06644168 -0.00416452  0.01388022 -0.03194802
#  -0.05079876  0.0137391   0.0587532  -0.02319264 -0.00416452  0.
#  -0.06096484 -0.00746276 -0.04450922  0.06786099  0.00828497  0.01952537
#  -0.05823029 -0.05605913  0.02738297 -0.00219455  0.051827   -0.04185401
#   0.00828497  0.         -0.03895469  0.0911735   0.          0.0587532
#  -0.01161659  0.05743524 -0.06096484 -0.00746276 -0.04450922  0.00828497
#  -0.06806125 -0.04283281 -0.04319064 -0.00416452  0.0587532  -0.02319264
#   0.02738297 -0.07167516 -0.00282266  0.02035885 -0.07520504 -0.05278541
#   0.00828497 -0.04502124  0.0587532  -0.00884506  0.01471554 -0.02183428
#  -0.04474772  0.08206188 -0.00884506 -0.07782872  0.02423722 -0.07898504
#  -0.05727172 -0.07970604 -0.09167207  0.00113948 -0.0535939   0.01425708
#  -0.07171944  0.00828497  0.02423722 -0.07898504 -0.03709297  0.02076215
#  -0.0417292   0.         -0.00633662 -0.00983837 -0.03914411  0.03625012
#  -0.04744614 -0.10715123  0.08984791 -0.01208871 -0.07520504 -0.03893806
#   0.03877699 -0.03853655 -0.02262401 -0.07898504 -0.02389359 -0.06029938
#  -0.01560235 -0.04911022 -0.08277592 -0.05233802 -0.07536586  0.00828497
#  -0.04319064 -0.02593426 -0.02188545  0.01425708 -0.01511082  0.01915518
#  -0.00633662 -0.08237288 -0.07520504 -0.05122384  0.00828497 -0.10615345
#  -0.05278541  0.051827    0.01060962 -0.0692184  -0.07171944 -0.07898504
#  -0.00416452 -0.07898504  0.          0.07144253  0.02738297 -0.01154331
#  -0.00980491  0.02538691  0.01264712 -0.09284669 -0.07898504 -0.00048511
#  -0.05218732 -0.08882646 -0.0431548  -0.04144043  0.01854723  0.00828497
#  -0.05605913 -0.05177181  0.00451924 -0.04404972 -0.04199389 -0.11658833
#  -0.06644168 -0.02180158 -0.01805367 -0.0972591  -0.02149929 -0.08277592
#  -0.02188545 -0.02183428 -0.00746276 -0.05605913 -0.00684681 -0.02183428
#  -0.08052316  0.00828497 -0.0990795  -0.05605913 -0.02183428 -0.02180158
#  -0.08052316  0.00828497  0.06786099  0.01845548 -0.05605913 -0.035988
#  -0.06644168 -0.01805367 -0.03887365  0.00828497 -0.02180158 -0.06440703
#   0.00828497 -0.01404495 -0.07898504 -0.02539606 -0.08277592 -0.04199389
#  -0.04327029 -0.03893806 -0.07898504 -0.08766773 -0.05605913 -0.01404495
#   0.00828497 -0.08237288  0.         -0.05420183  0.          0.05348753
#   0.01028223  0.          0.05619441  0.         -0.08882646  0.01764769
#   0.003453    0.03877699 -0.08369354 -0.07898504 -0.04865531  0.00828497
#  -0.00416452 -0.02593426 -0.02188545 -0.02183428  0.          0.05619441
#  -0.0977615  -0.03880859  0.02076215  0.00828497  0.06786099  0.01425708
#  -0.02635792 -0.07898504  0.02738297 -0.07183926  0.        ]

# %% [markdown]
# ## **Arts and Culture**

# %%
category_dfs['arts and culture']
embedding1 = category_dfs['arts and culture'].tokens.apply(generate_glove_embeddings)
em = pd.DataFrame(embedding1)
em.rename(columns = {'tokens':'embeddings'}, inplace = True)
embedding = category_dfs['arts and culture'].copy()
embedding
final_df2 = pd.concat([em, embedding], axis = 1)
final_df2
# Out:
#                                               embeddings            target  \
# 0      [0.07518134, 0.037957367, -0.009900642, -0.002...  arts and culture
# 1      [-0.0074627614, -0.077870324, 0.013579364, -0....  arts and culture
# 2      [-0.002929388, 0.029800858, 0.00018485538, -0....  arts and culture
# 3      [0.0, 0.051746417, -0.05433779, 0.01550076, 0....  arts and culture
# 4      [-0.019977637, -0.027807226, 0.04802774, -0.03...  arts and culture
# ...                                                  ...               ...
# 19928  [-0.011748527, -0.0033203035, -0.027415223, 0....  arts and culture
# 19929  [0.027382972, 0.08500374, 0.00019786485, 0.116...  arts and culture
# 19930  [-0.002929388, 0.03803761, 0.07864907, -0.0557...  arts and culture
# 19931  [0.02041562, -0.028789511, 0.0001472801, -0.04...  arts and culture
# 19932  [0.0125877075, -0.024745459, 0.0071372045, -0....  arts and culture
#
#                                                   tokens
# 0      (japan, foundation, travel, exhibition, title,...
# 1      (first, come, kolkata, school, believe, city, ...
# 2      (filmmaker, vivek, agnihotri, saturday, tell, ...
# 3      (mangaluru, mangalore, university, award, phd,...
# 4      (graphic, novelist, abhijeet, kini, give, read...
# ...                                                  ...
# 19928  (chandigarh, theme, tribe, india, fourth, edit...
# 19929  (pune, air, force, station, afs, lohegaon, dis...
# 19930  (filmmaker, mahesh, bhatt, confirm, adult, fil...
# 19931  (hour, half, long, wait, gate, finally, open, ...
# 19932  (abu, dhabi, cosmopolitan, business, city, get...
#
# [19933 rows x 3 columns]

# %%
final_df2.to_csv("/content/drive/MyDrive/TIL/Word_Embeddings/arts_and_culture_.csv")

# %% [markdown]
# ## **Automotives**

# %%
category_dfs['automotives']
embedding1 = category_dfs['automotives'].tokens.apply(generate_glove_embeddings)
em = pd.DataFrame(embedding1)
em.rename(columns = {'tokens':'embeddings'}, inplace = True)
embedding = category_dfs['automotives'].copy()
embedding
final_df3 = pd.concat([em, embedding], axis = 1)
final_df3
# Out:
#                                               embeddings       target  \
# 0      [-0.048018366, 0.021344757, -0.032308113, -0.0...  automotives
# 1      [0.092972584, 0.0, -0.018460117, -0.001665985,...  automotives
# 2      [-0.02065463, 0.030843038, -0.009804915, 0.034...  automotives
# 3      [0.050460763, 0.068941996, 0.003075177, -0.021...  automotives
# 4      [0.0, -0.057892542, -0.040311422, 0.023588333,...  automotives
# ...                                                  ...          ...
# 19947  [-0.0014565245, 0.092219695, -0.077870324, 0.0...  automotives
# 19948  [0.0, 0.0147119425, -0.030803375, 0.038334593,...  automotives
# 19949  [-0.044927403, -0.04018984, 0.0, 0.01915518, -...  automotives
# 19950  [-0.015765615, -0.08313125, -0.054995093, 0.0,...  automotives
# 19951  [-0.016166463, 0.017156502, -0.044322025, 0.03...  automotives
#
#                                                   tokens
# 0      (november, pv, sale, november, top, pv, sale, ...
# 1      (visteon, ecarx, jointly, support, lead, inveh...
# 2      (well, ajay, singh, run, state, bank, india, k...
# 3      (live, northeastern, united, state, must, snow...
# 4      (gefco, would, allow, cma, cgms, logistics, di...
# ...                                                  ...
# 19947  (technologically, car, come, long, way, past, ...
# 19948  (ticgard, kepong, professional, window, tint, ...
# 19949  (recent, spike, covid, case, impact, operation...
# 19950  (auto, market, reel, costofliving, squeeze, br...
# 19951  (care, beyond, point, mass, actually, cheap, l...
#
# [19952 rows x 3 columns]

# %%
final_df3.to_csv("/content/drive/MyDrive/TIL/Word_Embeddings/automotives_.csv")

# %% [markdown]
# ## **Books and Literature**

# %%
category_dfs['books and literature']
embedding1 = category_dfs['books and literature'].tokens.apply(generate_glove_embeddings)
em = pd.DataFrame(embedding1)
em.rename(columns = {'tokens':'embeddings'}, inplace = True)
embedding = category_dfs['books and literature'].copy()
embedding
final_df4 = pd.concat([em, embedding], axis = 1)
final_df4
# Out:
#                                               embeddings  \
# 0      [0.0011394823, -0.0066071735, 0.083295114, 0.0...
# 1      [0.0, 0.036713246, -0.07536586, -0.010626113, ...
# 2      [0.013554619, 0.0422884, -0.009122442, -0.1241...
# 3      [0.027544385, -0.065953456, -0.03767439, -0.00...
# 4      [-0.022914799, -0.043035608, -0.05874419, 0.0,...
# ...                                                  ...
# 19555  [-0.03289719, 0.0049916725, -0.006246912, 0.08...
# 19556  [0.0911735, 0.019309534, -0.056059126, 0.05046...
# 19557  [0.026056089, -0.029061222, 0.0, 0.0032683918,...
# 19558  [-0.09510309, 0.0, -0.025174899, -0.0074627614...
# 19559  [0.05254539, -0.08482387, 0.043759476, -0.0799...
#
#                      target                                             tokens
# 0      books and literature  (second, book, hidden, series, magnificent, fa...
# 1      books and literature  (gothgirl, raven, date, dream, boyfriend, comp...
# 2      books and literature  (bengaluru, former, bureaucrat, manu, baligar,...
# 3      books and literature  (volume, put, together, first, time, one, volu...
# 4      books and literature  (director, randhir, ranjan, roycast, shekhar, ...
# ...                     ...                                                ...
# 19555  books and literature  (claire, river, race, mailbox, receive, letter...
# 19556  books and literature  (nearly, twenty, year, live, california, march...
# 19557  books and literature  (j, r, longawaited, novel, william, gaddi, aut...
# 19558  books and literature  (john, braines, remarkable, first, novel, room...
# 19559  books and literature  (thiruvananthapuram, eminent, malayalam, write...
#
# [19560 rows x 3 columns]

# %%
final_df4.to_csv("/content/drive/MyDrive/TIL/Word_Embeddings/books_and_literature_.csv")

# %% [markdown]
# ## **Business and Finance**

# %%
category_dfs['business and finance']
embedding1 = category_dfs['business and finance'].tokens.apply(generate_glove_embeddings)
em = pd.DataFrame(embedding1)
em.rename(columns = {'tokens':'embeddings'}, inplace = True)
embedding = category_dfs['business and finance'].copy()
embedding
final_df5 = pd.concat([em, embedding], axis = 1)
final_df5
# Out:
#                                               embeddings  \
# 0      [0.013579364, -0.021801576, -0.038509574, -0.0...
# 1      [0.018681312, 0.037418462, -0.031666275, -0.00...
# 2      [-0.06352922, 0.001389485, 0.02652526, -0.0390...
# 3      [-0.06352922, 0.001389485, -0.0061807577, -0.0...
# 4      [-0.03328934, -0.057545174, -0.08367307, -0.02...
# ...                                                  ...
# 19899  [-0.047078848, -0.046634465, 0.0047493423, -0....
# 19900  [0.013579364, 0.01799695, 0.0, -0.080753505, -...
# 19901  [-0.032096393, 0.0, 0.0, -0.035366558, -0.0201...
# 19902  [-0.06435118, 0.0, -0.09134774, 0.0792667, 0.0...
# 19903  [0.019525371, -0.015685365, 0.008177213, -0.06...
#
#                      target                                             tokens
# 0      business and finance  (kolkata, state, cabinet, monday, give, approv...
# 1      business and finance  (bangalore, microfinance, institution, mfis, f...
# 2      business and finance  (new, delhi, three, month, rollout, new, indir...
# 3      business and finance  (new, delhi, apr, concern, recent, case, highi...
# 4      business and finance  (tweens, spend, report, billion, money, year, ...
# ...                     ...                                                ...
# 19899  business and finance  (possible, go, event, learn, attendance, way, ...
# 19900  business and finance  (kolkata, niti, aayog, order, detailed, evalua...
# 19901  business and finance  (div, classsectiondiv, classnormalthe, institu...
# 19902  business and finance  (keep, lowdenomination, currency, circulation,...
# 19903  business and finance  (mumbai, sep, gold, loan, financier, see, rise...
#
# [19904 rows x 3 columns]

# %%
final_df5.to_csv("/content/drive/MyDrive/TIL/Word_Embeddings/business_and_finance_.csv")

# %% [markdown]
# ## **Careers**

# %%
category_dfs['careers']
embedding1 = category_dfs['careers'].tokens.apply(generate_glove_embeddings)
em = pd.DataFrame(embedding1)
em.rename(columns = {'tokens':'embeddings'}, inplace = True)
embedding = category_dfs['careers'].copy()
embedding
final_df6 = pd.concat([em, embedding], axis = 1)
final_df6
# Out:
#                                               embeddings   target  \
# 0      [-0.07246368, -0.009022876, -0.074325755, -0.0...  careers
# 1      [-0.026967645, -0.06352922, -0.031040845, -0.0...  careers
# 2      [-0.015546732, -0.082498856, 0.03235175, -0.02...  careers
# 3      [-0.009838372, 0.020446358, 0.010609622, -0.00...  careers
# 4      [0.05879292, 0.05879292, -0.06962599, -0.05759...  careers
# ...                                                  ...      ...
# 19766  [-0.03539809, -0.0272506, -0.06962599, 0.00149...  careers
# 19767  [0.116959885, 0.022511942, 0.0028491805, -0.05...  careers
# 19768  [0.05879292, -0.055335652, -0.005565719, -0.02...  careers
# 19769  [0.047658462, 0.00898942, 0.03625012, 0.019155...  careers
# 19770  [-0.06259506, 0.07828949, 0.0027335049, 0.0056...  careers
#
#                                                   tokens
# 0      (job, title, business, administrator, hour, mo...
# 1      (engineer, new, career, lead, blue, chip, expe...
# 2      (commis, chef, exclusive, contract, caterer, c...
# 3      (research, nurse, full, training, offer, becom...
# 4      (client, client, lead, high, street, restauran...
# ...                                                  ...
# 19766  (harbour, jones, lead, independent, innovative...
# 19767  (jr, data, scientist, share, find, similar, ca...
# 19768  (client, look, lamp, development, system, engi...
# 19769  (customer, contact, centre, case, officer, lee...
# 19770  (work, digital, agency, unique, offering, brin...
#
# [19771 rows x 3 columns]

# %%
final_df6.to_csv("/content/drive/MyDrive/TIL/Word_Embeddings/careers_.csv")

# %% [markdown]
# ## **family and relationships**

# %%
category_dfs['family and relationships']
embedding1 = category_dfs['family and relationships'].tokens.apply(generate_glove_embeddings)
em = pd.DataFrame(embedding1)
em.rename(columns = {'tokens':'embeddings'}, inplace = True)
embedding = category_dfs['family and relationships'].copy()
embedding
final_df7 = pd.concat([em, embedding], axis = 1)
final_df7
# Out:
#                                               embeddings  \
# 0      [0.017163485, 0.09019718, 0.12805064, 0.0, -0....
# 1      [-0.06352922, 0.001389485, 0.001389485, -0.115...
# 2      [0.019525371, 0.001389485, 0.038585916, -0.089...
# 3      [-0.01721782, 0.0, -0.060404133, -0.023570327,...
# 4      [0.0437402, 0.038585916, -0.0634655, 0.0380987...
# ...                                                  ...
# 19835  [0.011563225, -0.089818865, -0.05170766, -0.05...
# 19836  [-0.00024123251, -0.042358413, -0.07536586, 0....
# 19837  [-0.062351078, -0.056059126, 0.0, 0.0, -0.0893...
# 19838  [0.027382972, 0.0, -0.022581501, 0.018265981, ...
# 19839  [0.024399888, -0.0066918586, 0.0, -0.06791235,...
#
#                          target  \
# 0      family and relationships
# 1      family and relationships
# 2      family and relationships
# 3      family and relationships
# 4      family and relationships
# ...                         ...
# 19835  family and relationships
# 19836  family and relationships
# 19837  family and relationships
# 19838  family and relationships
# 19839  family and relationships
#
#                                                   tokens
# 0      (kannada, actress, aishwarya, salimath, ready,...
# 1      (new, delhi, delhi, commission, woman, dcw, mo...
# 2      (mumbai, delhi, police, continue, record, stat...
# 3      (nagpur, durupyog, play, noga, wasahat, indora...
# 4      (chennai, police, find, body, yearold, homemak...
# ...                                                  ...
# 19835  (britain, continue, hold, sign, similar, deala...
# 19836  (wendy, will, date, indian, man, learn, tough,...
# 19837  (quite, year, rashmika, mandanna, college, stu...
# 19838  (pune, yearold, youth, arrest, thursday, day, ...
# 19839  (actor, renuka, shahane, marry, ashutosh, rana...
#
# [19840 rows x 3 columns]

# %%
final_df7.to_csv("/content/drive/MyDrive/TIL/Word_Embeddings/family_and_relationships_.csv")

# %% [markdown]
# ## **Food and Drinks**

# %%
category_dfs['food and drinks']
embedding1 = category_dfs['food and drinks'].tokens.apply(generate_glove_embeddings)
em = pd.DataFrame(embedding1)
em.rename(columns = {'tokens':'embeddings'}, inplace = True)
embedding = category_dfs['food and drinks'].copy()
embedding
final_df8 = pd.concat([em, embedding], axis = 1)
final_df8
# Out:
#                                               embeddings           target  \
# 0      [0.025660804, -0.05170766, 0.02652526, 0.07025...  food and drinks
# 1      [0.027382972, 0.019648537, -0.05751889, -0.064...  food and drinks
# 2      [-0.0417292, -0.062390566, 0.03407128, 0.02281...  food and drinks
# 3      [0.095408686, 0.048095062, -0.042832807, 0.045...  food and drinks
# 4      [0.0, -0.046258852, 0.058753196, 0.0, -0.03080...  food and drinks
# ...                                                  ...              ...
# 19920  [0.037978575, 0.046463966, 0.0, 0.0072600604, ...  food and drinks
# 19921  [0.09019718, 0.021616247, 0.049979836, -0.0232...  food and drinks
# 19922  [-0.04613663, -0.007130676, 0.0, -0.03595628, ...  food and drinks
# 19923  [-0.016807204, -0.04118435, -0.0074627614, -0....  food and drinks
# 19924  [0.054140445, -0.062698744, 0.06732723, 0.0385...  food and drinks
#
#                                                   tokens
# 0      (thane, hold, three, acre, fertile, agricultur...
# 1      (pune, doctor, notice, considerable, increase,...
# 2      (final, solution, destitute, home, recovery, h...
# 3      (northwestern, turkey, city, canakkale, tragic...
# 4      (yearsno, dance, seat, areasno, professional, ...
# ...                                                  ...
# 19920  (india, kisan, sangarsh, coordination, committ...
# 19921  (actress, shruti, haasan, last, see, telugu, f...
# 19922  (skip, bouquet, petalladen, bubble, bath, put,...
# 19923  (night, march, first, felt, dryness, throat, m...
# 19924  (puducherry, union, territory, police, monday,...
#
# [19925 rows x 3 columns]

# %%
final_df8.to_csv("/content/drive/MyDrive/TIL/Word_Embeddings/food_and_drinks_.csv")

# %% [markdown]
# ## **Health**

# %%
category_dfs['health']
embedding1 = category_dfs['health'].tokens.apply(generate_glove_embeddings)
em = pd.DataFrame(embedding1)
em.rename(columns = {'tokens':'embeddings'}, inplace = True)
embedding = category_dfs['health'].copy()
embedding
final_df9 = pd.concat([em, embedding], axis = 1)
final_df9
# Out:
#                                               embeddings  target  \
# 0      [0.014032086, 0.012647117, -0.05433779, -0.040...  health
# 1      [0.029113086, 0.0011394823, -0.0004687923, 0.0...  health
# 2      [0.029113086, -0.04793695, -0.064695045, 0.020...  health
# 3      [0.0437402, -0.014065171, -0.07519167, -0.0450...  health
# 4      [-0.00027761408, -0.023893595, 0.0021071928, 0...  health
# ...                                                  ...     ...
# 19914  [-0.06352922, 0.001389485, -0.051896516, 0.0, ...  health
# 19915  [0.029113086, 0.01845548, -0.010303025, 0.0249...  health
# 19916  [-0.011748527, -0.04118435, 0.00014366001, 0.0...  health
# 19917  [0.033165038, -0.039025117, -0.06002869, -0.01...  health
# 19918  [-0.040281087, -0.0684593, 0.014257083, -0.010...  health
#
#                                                   tokens
# 0      (nashik, maharashtra, university, health, scie...
# 1      (patna, second, wave, covid, pandemic, proving...
# 2      (patna, chief, minister, nitish, kumar, thursd...
# 3      (chennai, containment, effort, intensify, acro...
# 4      (shimla, use, mask, glove, increase, manifold,...
# ...                                                  ...
# 19914  (new, delhi, global, covid, case, surge, due, ...
# 19915  (patna, third, phase, nationwide, covid, vacci...
# 19916  (chandigarh, march, record, almost, sixtime, s...
# 19917  (four, month, age, group, complete, target, fi...
# 19918  (health, risk, child, older, adult, people, he...
#
# [19919 rows x 3 columns]

# %%
final_df9.to_csv("/content/drive/MyDrive/TIL/Word_Embeddings/health_.csv")

# %% [markdown]
# ## **movies**

# %%
category_dfs['movies']
embedding1 = category_dfs['movies'].tokens.apply(generate_glove_embeddings)
em = pd.DataFrame(embedding1)
em.rename(columns = {'tokens':'embeddings'}, inplace = True)
embedding = category_dfs['movies'].copy()
embedding
final_df10 = pd.concat([em, embedding], axis = 1)
final_df10
# Out:
#                                               embeddings  target  \
# 0      [0.055371266, -0.038808588, -0.0977615, -0.063...  movies
# 1      [0.036713246, -0.017732438, 0.04370352, 0.0252...  movies
# 2      [-0.052060805, 0.032974854, -0.04285579, 0.0, ...  movies
# 3      [-0.059051447, -0.033459473, 0.04029088, -0.06...  movies
# 4      [0.049059942, -0.05809763, -0.04271748, 0.0271...  movies
# ...                                                  ...     ...
# 19959  [0.038350347, 0.053957645, -0.065037556, 0.030...  movies
# 19960  [0.0, 0.055910513, 0.034909032, -0.01318562, 0...  movies
# 19961  [-0.019076187, -0.07956566, 0.070633486, 0.031...  movies
# 19962  [0.02194696, -0.0037143496, -0.02262401, 0.066...  movies
# 19963  [0.024399888, 0.038960133, -0.023257846, -0.08...  movies
#
#                                                   tokens
# 0      (crew, member, help, make, directorial, debut,...
# 1      (raven, chooses, orgasm, part, one, fantasy, s...
# 2      (kourtney, kardashian, scott, disick, split, a...
# 3      (time, problem, fan, noticeable, promotion, pr...
# 4      (mammootty, hint, yet, another, blockbuster, t...
# ...                                                  ...
# 19959  (sanya, malhotra, await, release, next, kathal...
# 19960  (muchawaited, telugu, film, agent, star, akhil...
# 19961  (music, composer, rahul, raj, busy, compose, s...
# 19962  (anil, sharma, back, sequel, iconic, gadar, ye...
# 19963  (actor, karthi, last, see, tamil, film, ponniy...
#
# [19964 rows x 3 columns]

# %%
final_df10.to_csv("/content/drive/MyDrive/TIL/Word_Embeddings/movies_.csv")

# %% [markdown]
# ## **music and audio**

# %%
category_dfs['music and audio']
embedding1 = category_dfs['music and audio'].tokens.apply(generate_glove_embeddings)
em = pd.DataFrame(embedding1)
em.rename(columns = {'tokens':'embeddings'}, inplace = True)
embedding = category_dfs['music and audio'].copy()
embedding
final_df11 = pd.concat([em, embedding], axis = 1)
final_df11
# Out:
#                                               embeddings           target  \
# 0      [0.008656172, 0.019012911, -0.03579998, 0.0437...  music and audio
# 1      [0.08362419, 0.012511327, 0.03195927, 0.022485...  music and audio
# 2      [-0.0074627614, -0.04534745, -0.008089382, -0....  music and audio
# 3      [-0.019076187, -0.022914799, -0.033790663, 0.0...  music and audio
# 4      [0.026300821, -0.01882515, 0.040970158, -0.063...  music and audio
# ...                                                  ...              ...
# 19930  [-0.078224674, -0.02152608, 0.08362419, -0.075...  music and audio
# 19931  [0.040549878, -0.011527377, 0.057094216, 0.012...  music and audio
# 19932  [0.074542575, 0.0, 0.025285669, 0.012559309, -...  music and audio
# 19933  [-0.021801576, -0.0019081724, -0.070495844, -0...  music and audio
# 19934  [0.11222864, 0.0, 0.056171212, -0.041025713, -...  music and audio
#
#                                                   tokens
# 0      (varanasi, emotional, appeal, jail, mafia, muk...
# 1      (audio, c, v, kumars, thirukumaran, entertainm...
# 2      (first, day, shravan, maas, celebrate, devotee...
# 3      (music, director, raja, narayan, deb, almost, ...
# 4      (rapper, frank, oceans, new, album, rumour, ca...
# ...                                                  ...
# 19930  (increase, clarity, audio, ensure, sound, guit...
# 19931  (citroen, set, launch, c, india, market, july,...
# 19932  (track, sohne, di, pasand, become, quite, roar...
# 19933  (state, sue, obama, administration, issue, gui...
# 19934  (video, yearold, boy, sing, classical, song, t...
#
# [19935 rows x 3 columns]

# %%
final_df11.to_csv("/content/drive/MyDrive/TIL/Word_Embeddings/music_and_audio_.csv")

# %%
category_dfs['news and politics']
embedding1 = category_dfs['news and politics'].tokens.apply(generate_glove_embeddings)
em = pd.DataFrame(embedding1)
em.rename(columns = {'tokens':'embeddings'}, inplace = True)
embedding = category_dfs['news and politics'].copy()
embedding
final_df12 = pd.concat([em, embedding], axis = 1)
final_df12
# Out:
#                                               embeddings             target  \
# 0      [0.04257759, -0.030348832, 0.04257759, -0.0303...  news and politics
# 1      [-0.08882646, -0.016166463, -0.057892542, -0.0...  news and politics
# 2      [0.04377553, -0.00016055942, -0.05183334, -0.0...  news and politics
# 3      [-0.061253663, -0.005378024, -0.030803375, 0.0...  news and politics
# 4      [-0.027505241, 0.040779337, 0.018589303, 0.024...  news and politics
# ...                                                  ...                ...
# 19946  [0.032755602, -0.027307766, 0.012075496, 0.049...  news and politics
# 19947  [-0.023893595, -0.077870324, -0.076517895, -0....  news and politics
# 19948  [-0.038950272, 0.0013705146, -0.0393516, 0.038...  news and politics
# 19949  [0.0026147836, 0.0021679725, -0.07215045, -0.0...  news and politics
# 19950  [-0.08530069, 0.013926659, -0.02111542, 0.0, 0...  news and politics
#
#                                                   tokens
# 0      (bangladesh, journal, bangladesh, journal, inn...
# 1      (say, care, would, stop, fight, russia, aggres...
# 2      (jail, kremlin, critic, alexei, navalny, tuesd...
# 3      (here, tip, professional, scoffer, sneer, trum...
# 4      (bro, fire, surf, one, worlds, dangerous, wave...
# ...                                                  ...
# 19946  (dehradun, ongoing, investigation, uttarakhand...
# 19947  (use, come, ask, win, election, use, offer, mo...
# 19948  (february, deputy, superintendent, police, sha...
# 19949  (ludhiana, leader, shiromani, akali, dal, wedn...
# 19950  (washington, nikki, haley, exgovernor, south, ...
#
# [19951 rows x 3 columns]

# %%
final_df12.to_csv("/content/drive/MyDrive/TIL/Word_Embeddings/news_and_politics_.csv")

# %%
category_dfs['personal finance']
embedding1 = category_dfs['personal finance'].tokens.apply(generate_glove_embeddings)
em = pd.DataFrame(embedding1)
em.rename(columns = {'tokens':'embeddings'}, inplace = True)
embedding = category_dfs['personal finance'].copy()
embedding
final_df13 = pd.concat([em, embedding], axis = 1)
final_df13
# Out:
#                                               embeddings            target  \
# 0      [0.037978575, 0.025229463, -0.09322947, -0.045...  personal finance
# 1      [0.019525371, -0.015132241, -0.08596944, -0.04...  personal finance
# 2      [-0.06352922, 0.001389485, -0.11026699, -0.064...  personal finance
# 3      [-0.02024317, 0.03620368, -0.11534062, -0.0595...  personal finance
# 4      [0.07423546, -0.10294973, -0.0953787, -0.03387...  personal finance
# ...                                                  ...               ...
# 19877  [-0.051224194, -0.041077506, 0.05051178, -0.01...  personal finance
# 19878  [0.019525371, 0.058567137, 0.04980832, -0.0616...  personal finance
# 19879  [-0.06352922, 0.001389485, 0.001389485, -0.023...  personal finance
# 19880  [-0.06352922, 0.001389485, 0.0036411565, -0.00...  personal finance
# 19881  [-0.0575926, -0.0098333815, -0.087140396, 0.03...  personal finance
#
#                                                   tokens
# 0      (india, part, plan, strengthen, security, tie,...
# 1      (mumbai, didnt, think, current, volatility, ru...
# 2      (new, delhi, finance, minister, nirmala, sitha...
# 3      (everybody, love, arbitrage, fund, since, unio...
# 4      (jammu, bill, seek, enable, employee, increase...
# ...                                                  ...
# 19877  (different, cost, component, like, preferentia...
# 19878  (mumbai, piramal, realty, real, estate, arm, p...
# 19879  (new, delhi, delhi, development, authority, dd...
# 19880  (new, delhi, allahabad, bank, idbi, top, list,...
# 19881  (high, property, price, india, deter, investor...
#
# [19882 rows x 3 columns]

# %%
final_df13.to_csv("/content/drive/MyDrive/TIL/Word_Embeddings/personal_and_finanace_.csv")

# %%
category_dfs['pets']
embedding1 = category_dfs['pets'].tokens.apply(generate_glove_embeddings)
em = pd.DataFrame(embedding1)
em.rename(columns = {'tokens':'embeddings'}, inplace = True)
embedding = category_dfs['pets'].copy()
embedding
final_df14 = pd.concat([em, embedding], axis = 1)
final_df14
# Out:
#                                               embeddings target  \
# 0      [-0.006922849, -0.02849333, -0.009514161, 0.02...   pets
# 1      [0.019525371, 0.020358846, 0.0, -0.056059126, ...   pets
# 2      [-0.06405064, 0.013312213, -0.017672868, 0.118...   pets
# 3      [0.041940637, 0.059553254, 0.03420705, 0.00702...   pets
# 4      [0.027382972, 0.03925317, 0.005790466, -0.0611...   pets
# ...                                                  ...    ...
# 19925  [-0.08530069, 0.019877678, 0.09394922, 0.05053...   pets
# 19926  [-0.06352922, 0.001389485, -0.02525633, 0.0571...   pets
# 19927  [0.001389485, 0.015416753, -0.0018743384, -0.0...   pets
# 19928  [-0.06352922, 0.001389485, -0.033212136, -0.05...   pets
# 19929  [0.013579364, 0.009476305, 0.0, -0.05856751, 0...   pets
#
#                                                   tokens
# 0      (attracts, lot, people, curly, lock, win, smil...
# 1      (mumbai, two, covid, year, record, low, noise,...
# 2      (london, ever, heard, canine, living, clothes,...
# 3      (hyderabad, metro, service, expand, connect, l...
# 4      (pune, animal, activist, tuesday, accuse, civi...
# ...                                                  ...
# 19925  (washington, nursing, broken, heart, brain, gi...
# 19926  (new, delhi, senior, bjp, leader, yashwant, si...
# 19927  (delhi, zoo, official, decision, put, white, t...
# 19928  (new, delhi, staff, selection, commission, ssc...
# 19929  (kolkata, crack, ileague, club, body, open, mo...
#
# [19930 rows x 3 columns]

# %%
final_df14.to_csv("/content/drive/MyDrive/TIL/Word_Embeddings/pets_.csv")

# %%
category_dfs['pharmaceuticals, conditions, and symptoms']
embedding1 = category_dfs['pharmaceuticals, conditions, and symptoms'].tokens.apply(generate_glove_embeddings)
em = pd.DataFrame(embedding1)
em.rename(columns = {'tokens':'embeddings'}, inplace = True)
embedding = category_dfs['pharmaceuticals, conditions, and symptoms'].copy()
embedding
final_df15 = pd.concat([em, embedding], axis = 1)
final_df15
# Out:
#                                               embeddings  \
# 0      [0.033298865, 0.0, -0.061734434, -0.0500739, 0...
# 1      [0.054306254, -0.016407952, 0.009361258, 0.0, ...
# 2      [0.048764963, 0.039601047, 0.066178955, -0.075...
# 3      [-0.044874147, -0.04317094, 0.026078431, -0.01...
# 4      [0.014688087, 0.16560239, -0.122534044, 0.0, 0...
# ...                                                  ...
# 19995  [-0.01972608, 0.020682504, 0.01919685, 0.08120...
# 19996  [-0.036852468, -0.03718729, -0.017077819, -0.0...
# 19997  [-0.04965472, -0.023893595, -0.0064084763, 0.0...
# 19998  [-0.018279884, -0.05962837, 0.0, -0.03572012, ...
# 19999  [-0.05306923, -0.063399434, 0.059504606, 0.049...
#
#                                           target  \
# 0      pharmaceuticals, conditions, and symptoms
# 1      pharmaceuticals, conditions, and symptoms
# 2      pharmaceuticals, conditions, and symptoms
# 3      pharmaceuticals, conditions, and symptoms
# 4      pharmaceuticals, conditions, and symptoms
# ...                                          ...
# 19995  pharmaceuticals, conditions, and symptoms
# 19996  pharmaceuticals, conditions, and symptoms
# 19997  pharmaceuticals, conditions, and symptoms
# 19998  pharmaceuticals, conditions, and symptoms
# 19999  pharmaceuticals, conditions, and symptoms
#
#                                                   tokens
# 0      (bsd, rubiscospecific, assembly, chaperone, fo...
# 1      (detection, designer, steroid, methylstenbolon...
# 2      (atrioventricular, conduction, disturbance, ea...
# 3      (experience, concern, lesbian, gay, bisexual, ...
# 4      (visual, portable, strategy, copperii, detecti...
# ...                                                  ...
# 19995  (municipal, solid, waste, landfill, obvious, i...
# 19996  (food, environment, cause, obesity, epidemic, ...
# 19997  (cue, use, black, fly, simulium, annulus, attr...
# 19998  (enantioselective, quenching, roomtemperature,...
# 19999  (decrease, regional, cerebral, blood, flow, no...
#
# [20000 rows x 3 columns]

# %%
final_df15.to_csv("/content/drive/MyDrive/TIL/Word_Embeddings/pharmaceuticals_conditions_and_symptoms_.csv")

# %%
category_dfs['real estate']
embedding1 = category_dfs['real estate'].tokens.apply(generate_glove_embeddings)
em = pd.DataFrame(embedding1)
em.rename(columns = {'tokens':'embeddings'}, inplace = True)
embedding = category_dfs['real estate'].copy()
embedding
final_df16 = pd.concat([em, embedding], axis = 1)
final_df16
# Out:
#                                               embeddings       target  \
# 0      [0.012964742, -0.049493093, -0.055335652, -0.0...  real estate
# 1      [0.031661406, -0.016807448, 0.028908243, -0.04...  real estate
# 2      [0.018196529, -0.009378158, -0.03161209, -0.07...  real estate
# 3      [0.028516347, -0.061646245, -0.04420792, -0.01...  real estate
# 4      [0.049396485, -0.06654749, 0.038544763, 0.0151...  real estate
# ...                                                  ...          ...
# 19899  [-0.05754394, 0.032209914, -0.061646245, -0.04...  real estate
# 19900  [0.06038356, -0.003471133, -0.06313005, -0.046...  real estate
# 19901  [0.013579364, 0.05587144, 0.049854353, 0.0, -0...  real estate
# 19902  [0.025846329, -0.047411993, -0.06352922, -0.08...  real estate
# 19903  [-0.06352922, 0.001389485, -0.0721506, -0.0337...  real estate
#
#                                                   tokens
# 0      (every, goan, look, forward, budget, hope, anx...
# 1      (kanpur, dwarka, indore, pushkar, current, fin...
# 2      (story, originally, appear, jan, mumbai, ajay,...
# 3      (palghar, real, estate, agent, adjoin, thane, ...
# 4      (visakhapatnam, ap, build, construction, worke...
# ...                                                  ...
# 19899  (great, noida, real, estate, project, resident...
# 19900  (idbi, bank, make, successful, transformation,...
# 19901  (kolkata, sleuth, probe, trinetra, muddle, try...
# 19902  (jaipur, transition, new, order, regime, usual...
# 19903  (new, delhi, jan, housing, sale, drop, per, ce...
#
# [19904 rows x 3 columns]

# %%
final_df16.to_csv("/content/drive/MyDrive/TIL/Word_Embeddings/real_estate_.csv")

# %%
category_dfs['shopping']
embedding1 = category_dfs['shopping'].tokens.apply(generate_glove_embeddings)
em = pd.DataFrame(embedding1)
em.rename(columns = {'tokens':'embeddings'}, inplace = True)
embedding = category_dfs['shopping'].copy()
embedding
final_df17 = pd.concat([em, embedding], axis = 1)
final_df17
# Out:
#                                               embeddings    target  \
# 0      [-0.01721782, 0.013256208, -0.042840805, -0.02...  shopping
# 1      [0.012511327, -0.016630217, -0.04322924, -0.03...  shopping
# 2      [0.000835586, -0.063034385, -0.015512615, 0.01...  shopping
# 3      [0.025660804, -0.12406182, -0.0015974406, 0.03...  shopping
# 4      [0.025846329, 0.038585916, -0.023999577, -0.04...  shopping
# ...                                                  ...       ...
# 19921  [0.013579364, 0.0, 0.008177213, 0.028037526, 0...  shopping
# 19922  [-0.06352922, 0.001389485, 0.001389485, -0.041...  shopping
# 19923  [-0.019172031, -0.02262401, -0.16000539, -0.03...  shopping
# 19924  [-0.07062508, 0.0, -0.0848494, -0.021221593, -...  shopping
# 19925  [0.037776336, 0.0404785, -0.006846811, -0.0287...  shopping
#
#                                                   tokens
# 0      (nagpur, grow, discontent, among, shopkeeper, ...
# 1      (c, provide, easy, way, new, upcoming, store, ...
# 2      (agra, week, daylight, robbery, r, lakh, worth...
# 3      (thane, wine, shop, employee, attack, robbed, ...
# 4      (jaipur, police, team, investigate, acid, atta...
# ...                                                  ...
# 19921  (kolkata, senco, gold, diamond, one, lead, jew...
# 19922  (new, delhi, delhi, government, tuesday, bid, ...
# 19923  (claw, back, cautious, expansion, cloud, kitch...
# 19924  (begin, hadnt, define, role, well, thing, like...
# 19925  (million, australian, close, half, population,...
#
# [19926 rows x 3 columns]

# %%
final_df17.to_csv("/content/drive/MyDrive/TIL/Word_Embeddings/shopping_.csv")

# %%
category_dfs['sports']
embedding1 = category_dfs['sports'].tokens.apply(generate_glove_embeddings)
em = pd.DataFrame(embedding1)
em.rename(columns = {'tokens':'embeddings'}, inplace = True)
embedding = category_dfs['sports'].copy()
embedding
final_df18 = pd.concat([em, embedding], axis = 1)
final_df18
# Out:
#                                               embeddings  target  \
# 0      [-0.015602353, -0.003308999, -0.02525633, -0.0...  sports
# 1      [-0.011748527, -0.042832807, -0.019857176, -0....  sports
# 2      [0.053210273, 0.0073569613, -0.023999577, 0.00...  sports
# 3      [-0.03392712, 0.024237225, -0.0020954588, -0.0...  sports
# 4      [-0.01605144, -0.04534745, -0.07215045, -0.084...  sports
# ...                                                  ...     ...
# 19942  [0.013579364, 0.0422884, 0.04983406, 0.0407437...  sports
# 19943  [-0.016499653, -0.08874839, 0.10133958, -0.009...  sports
# 19944  [0.04173316, -0.02929278, -0.002450541, -0.023...  sports
# 19945  [0.041940637, 0.0, 0.0, 0.080533355, 0.0656134...  sports
# 19946  [0.022195019, 0.01967187, -0.022581501, -0.082...  sports
#
#                                                   tokens
# 0      (like, guy, senior, candidate, fall, regular, ...
# 1      (chandigarh, city, still, devoid, velodrome, b...
# 2      (bagger, sport, team, sport, superstore, bagge...
# 3      (birmingham, one, worst, performances, recent,...
# 4      (mohali, day, shiromani, akali, dal, sad, lead...
# ...                                                  ...
# 19942  (kolkata, former, olympian, sibling, archer, d...
# 19943  (margao, brace, subhash, singh, help, pune, fc...
# 19944  (opposite, direction, saddle, mark, could, kee...
# 19945  (hyderabad, kvr, hemanth, kumar, bag, allindia...
# 19946  (vadodara, national, youth, league, football, ...
#
# [19947 rows x 3 columns]

# %%
final_df18.to_csv("/content/drive/MyDrive/TIL/Word_Embeddings/sports_.csv")

# %%
category_dfs['style and fashion']
embedding1 = category_dfs['style and fashion'].tokens.apply(generate_glove_embeddings)
em = pd.DataFrame(embedding1)
em.rename(columns = {'tokens':'embeddings'}, inplace = True)
embedding = category_dfs['style and fashion'].copy()
embedding
final_df19 = pd.concat([em, embedding], axis = 1)
final_df19
# Out:
#                                               embeddings             target  \
# 0      [-0.06352922, 0.001389485, -0.025450002, 0.013...  style and fashion
# 1      [-0.069111854, -0.051868647, -0.08974306, 0.06...  style and fashion
# 2      [-0.04534745, -0.025853274, -0.0095948335, 0.0...  style and fashion
# 3      [0.03343729, 0.02652526, -0.021834278, 0.01967...  style and fashion
# 4      [0.0086236205, 0.02652526, -0.04534745, -0.048...  style and fashion
# ...                                                  ...                ...
# 19946  [0.0815667, -0.032308113, -0.034045458, 0.0258...  style and fashion
# 19947  [0.08057142, 0.0544409, 0.0073569613, -0.00640...  style and fashion
# 19948  [0.03093016, 0.006313714, -0.009935616, 0.0201...  style and fashion
# 19949  [-0.06352922, 0.001389485, 0.0404785, -0.01640...  style and fashion
# 19950  [0.04521026, 0.045323577, -0.043270294, -0.069...  style and fashion
#
#                                                   tokens
# 0      (new, delhi, reliance, brand, part, mukesh, am...
# 1      (heady, cocktail, style, popup, shop, music, m...
# 2      (day, ago, urfi, javed, got, heat, argument, s...
# 3      (bhubaneswar, three, student, national, instit...
# 4      (spread, three, day, jury, meet, thetimes, unl...
# ...                                                  ...
# 19946  (amazon, sale, present, excite, opportunity, g...
# 19947  (deepika, padukone, sport, black, mermaid, dre...
# 19948  (septum, pierce, moment, sun, celebrity, like,...
# 19949  (new, delhi, australian, designer, create, sti...
# 19950  (prone, continuously, hence, occupational, haz...
#
# [19951 rows x 3 columns]

# %%
final_df19.to_csv("/content/drive/MyDrive/TIL/Word_Embeddings/style_and_fashion_.csv")

# %%
category_dfs['technology and computing']
embedding1 = category_dfs['technology and computing'].tokens.apply(generate_glove_embeddings)
em = pd.DataFrame(embedding1)
em.rename(columns = {'tokens':'embeddings'}, inplace = True)
embedding = category_dfs['technology and computing'].copy()
embedding
final_df20 = pd.concat([em, embedding], axis = 1)
final_df20
# Out:
#                                               embeddings  \
# 0      [0.038585916, 0.037978575, 0.017999828, -0.041...
# 1      [-0.09198022, -0.028475896, -0.100625165, -0.0...
# 2      [-0.008327144, -0.008327144, 0.013194804, -0.0...
# 3      [-0.018053673, -0.06435118, 0.050153613, 0.079...
# 4      [-0.0019353746, 0.03656672, -0.063739635, -0.0...
# ...                                                  ...
# 19859  [0.049396485, 0.06855351, 0.049023837, 0.06211...
# 19860  [0.0056165364, 0.0, 0.0, 0.0, -0.021834278, -0...
# 19861  [-0.044927403, -0.07515458, 0.021509638, -0.08...
# 19862  [0.0056165364, 0.020358846, -0.063034385, 0.0,...
# 19863  [0.013554619, 0.0, -0.038286813, -0.066634186,...
#
#                          target  \
# 0      technology and computing
# 1      technology and computing
# 2      technology and computing
# 3      technology and computing
# 4      technology and computing
# ...                         ...
# 19859  technology and computing
# 19860  technology and computing
# 19861  technology and computing
# 19862  technology and computing
# 19863  technology and computing
#
#                                                   tokens
# 0      (police, india, symbol, government, visible, s...
# 1      (believe, everyone, learn, code, skill, cod, d...
# 2      (br, br, pantaloon, retail, r, attract, buy, i...
# 3      (also, keep, intact, shallow, back, sit, chair...
# 4      (stockholm, quantum, physic, invisibility, clo...
# ...                                                  ...
# 19859  (visakhapatnam, artificial, intelligence, mach...
# 19860  (kochi, anfil, shajo, thirdyear, student, toc,...
# 19861  (recent, decision, us, appellate, court, refer...
# 19862  (kochi, two, week, edusap, intelligent, studen...
# 19863  (bengaluru, yearold, assistant, professor, rep...
#
# [19864 rows x 3 columns]

# %%
final_df20.to_csv("/content/drive/MyDrive/TIL/Word_Embeddings/technology_and_computing_.csv")

# %%
category_dfs['healthy living']
embedding1 = category_dfs['healthy living'].tokens.apply(generate_glove_embeddings)
em = pd.DataFrame(embedding1)
em.rename(columns = {'tokens':'embeddings'}, inplace = True)
embedding = category_dfs['healthy living'].copy()
embedding
final_df21 = pd.concat([em, embedding], axis = 1)
final_df21
# Out:
#                                               embeddings          target  \
# 0      [-0.029101616, 0.0078081964, -0.038141903, -0....  healthy living
# 1      [-0.010233113, 0.046449784, -0.060299378, -0.0...  healthy living
# 2      [-0.02208984, -0.025976896, -0.054860264, -0.0...  healthy living
# 3      [-0.029439371, -0.063745216, -0.075855196, 0.0...  healthy living
# 4      [0.015308537, 0.012075496, -0.07296657, 0.0302...  healthy living
# ...                                                  ...             ...
# 19852  [0.02797004, 0.03533413, 0.033611584, -0.08878...  healthy living
# 19853  [0.0, 0.024237225, -0.0074627614, -0.04476505,...  healthy living
# 19854  [-0.025565533, -0.05103225, -0.026861606, -0.0...  healthy living
# 19855  [-0.021725731, -0.00685773, -0.04474772, -0.02...  healthy living
# 19856  [0.03022012, -0.039025117, -0.025853274, -0.10...  healthy living
#
#                                                   tokens
# 0      (underlie, medical, issue, like, vitamin, defi...
# 1      (stage, grief, mean, tell, feel, feel, exactly...
# 2      (youre, among, always, experiment, western, fa...
# 3      (lucknow, equate, tobacco, weapon, mass, destr...
# 4      (criminal, investigation, underway, six, peopl...
# ...                                                  ...
# 19852  (ahmedabad, vinay, oza, call, change, engineer...
# 19853  (introchances, one, first, place, turn, quick,...
# 19854  (key, manage, conflict, first, foremost, recog...
# 19855  (christmas, fever, get, everyone, infect, thus...
# 19856  (six, month, ago, decide, take, plunge, get, c...
#
# [19857 rows x 3 columns]

# %%
final_df21.to_csv("/content/drive/MyDrive/TIL/Word_Embeddings/healthy_living_.csv")

# %%
category_dfs['hobbies and interests']
embedding1 = category_dfs['hobbies and interests'].tokens.apply(generate_glove_embeddings)
em = pd.DataFrame(embedding1)
em.rename(columns = {'tokens':'embeddings'}, inplace = True)
embedding = category_dfs['hobbies and interests'].copy()
embedding
final_df22 = pd.concat([em, embedding], axis = 1)
final_df22
# Out:
#                                               embeddings  \
# 0      [-0.08080925, 0.05943162, 0.04019517, 0.044093...
# 1      [-0.043573905, -0.045794636, -0.09687876, -0.0...
# 2      [-0.057374973, -0.06659152, 0.029462133, -0.03...
# 3      [0.0040154443, -0.0977615, -0.07116422, -0.071...
# 4      [-0.06352922, 0.001389485, -0.050968047, 0.015...
# ...                                                  ...
# 19865  [0.0, 0.0, -0.08984347, 0.009815102, 0.0114977...
# 19866  [-0.077870324, -0.03767439, -0.03893806, -0.00...
# 19867  [0.06374874, -0.08080192, -0.038523063, 0.0380...
# 19868  [0.049396485, -0.021033032, -0.056059126, -0.0...
# 19869  [-0.009804915, -0.0031425536, -0.06574306, -0....
#
#                       target  \
# 0      hobbies and interests
# 1      hobbies and interests
# 2      hobbies and interests
# 3      hobbies and interests
# 4      hobbies and interests
# ...                      ...
# 19865  hobbies and interests
# 19866  hobbies and interests
# 19867  hobbies and interests
# 19868  hobbies and interests
# 19869  hobbies and interests
#
#                                                   tokens
# 0      (arent, satoshi, tajiri, japanese, designer, i...
# 1      (president, trump, pick, replace, antonin, sca...
# 2      (hardly, occasion, software, professional, aru...
# 3      (program, help, explore, write, workshop, kid,...
# 4      (new, delhi, royal, mail, go, credit, populari...
# ...                                                  ...
# 19865  (ayushmann, khurrana, apply, fly, license, you...
# 19866  (come, together, many, artist, art, lover, cit...
# 19867  (tv, industry, know, gruelling, schedule, long...
# 19868  (visakhapatnam, newly, year, new, beginning, n...
# 19869  (singh, claim, pay, monthly, bill, sims, posse...
#
# [19870 rows x 3 columns]

# %%
final_df22.to_csv("/content/drive/MyDrive/TIL/Word_Embeddings/hobbies_and_interests_.csv")

# %%
category_dfs['home and garden']
embedding1 = category_dfs['home and garden'].tokens.apply(generate_glove_embeddings)
em = pd.DataFrame(embedding1)
em.rename(columns = {'tokens':'embeddings'}, inplace = True)
embedding = category_dfs['home and garden'].copy()
embedding
final_df23 = pd.concat([em, embedding], axis = 1)
final_df23
# Out:
#                                               embeddings           target  \
# 0      [-0.02327495, -0.00018387317, -0.04534745, -0....  home and garden
# 1      [-0.06352922, 0.001389485, 0.0, -0.05278541, -...  home and garden
# 2      [-0.0470141, -0.009351195, 0.049697038, -0.078...  home and garden
# 3      [-0.10110509, -0.080523156, -0.016166463, 0.00...  home and garden
# 4      [0.0077687614, 0.03723866, 0.024815511, -0.057...  home and garden
# ...                                                  ...              ...
# 19905  [0.041940637, 0.010947246, 0.021632204, 0.0166...  home and garden
# 19906  [-0.007342085, 0.08997911, -0.01972608, 0.0486...  home and garden
# 19907  [-0.009391723, -0.091622636, -0.08323206, -0.0...  home and garden
# 19908  [0.013554619, 0.024998799, 0.041790027, -0.078...  home and garden
# 19909  [-0.04474772, -0.06791235, -0.10340449, 0.0215...  home and garden
#
#                                                   tokens
# 0      (unsolicited, valentine, day, public, service,...
# 1      (new, delhi, tailormade, low, bounce, fast, gr...
# 2      (married, couple, spouse, increase, togetherne...
# 3      (advice, take, care, farm, yamanappa, benefici...
# 4      (thousand, goans, tourist, alike, flock, samba...
# ...                                                  ...
# 19905  (hyderabad, telangana, rashtra, samithi, trs, ...
# 19906  (vijaywada, vijayawada, municipal, corporation...
# 19907  (th, defeat, season, new, york, pull, point, l...
# 19908  (bengaluru, nationwide, lockdown, enforce, res...
# 19909  (get, marry, settle, us, say, take, rajgopalan...
#
# [19910 rows x 3 columns]

# %%
final_df23.to_csv("/content/drive/MyDrive/TIL/Word_Embeddings/home_and_garden.csv")

# %%
category_dfs['television']
embedding1 = category_dfs['television'].tokens.apply(generate_glove_embeddings)
em = pd.DataFrame(embedding1)
em.rename(columns = {'tokens':'embeddings'}, inplace = True)
embedding = category_dfs['television'].copy()
embedding
final_df24 = pd.concat([em, embedding], axis = 1)
final_df24
# Out:
#                                               embeddings      target  \
# 0      [0.02797004, 0.06374874, -0.0049599423, 0.0, 0...  television
# 1      [0.019525371, 0.06374874, -0.060530707, 0.0342...  television
# 2      [0.037531357, -0.011527377, 0.03343763, 0.0593...  television
# 3      [0.058178455, 0.0, 0.03566435, 0.049059942, -0...  television
# 4      [0.12769732, 0.03097391, 0.0, -0.10444688, 0.0...  television
# ...                                                  ...         ...
# 19960  [0.037978575, 0.02671257, -6.179958e-05, -0.04...  television
# 19961  [-0.06352922, 0.001389485, -0.050164126, -0.08...  television
# 19962  [0.043759476, 0.06374874, 0.0001472801, 0.0219...  television
# 19963  [-0.06352922, -0.042988747, 0.06374874, -0.020...  television
# 19964  [0.027382972, -0.008499027, -0.010233113, 0.03...  television
#
#                                                   tokens
# 0      (ahmedabad, tv, burn, shortcircuit, cable, con...
# 1      (mumbai, tv, credit, service, financial, socie...
# 2      (google, set, motion, competitor, amazon, blas...
# 3      (sensation, mollywood, megastar, mammootty, ce...
# 4      (priyanka, naidu, madhubabu, celebrate, seven,...
# ...                                                  ...
# 19960  (india, electricity, fluctuation, trip, common...
# 19961  (new, delhi, planning, buying, scooter, rs, di...
# 19962  (malayalam, tv, long, list, reality, show, boa...
# 19963  (new, mythological, tv, show, dnyaneshwar, mau...
# 19964  (pune, veteran, stage, film, television, actor...
#
# [19965 rows x 3 columns]

# %%
final_df24.to_csv("/content/drive/MyDrive/TIL/Word_Embeddings/television_.csv")

# %%
category_dfs['travel']
embedding1 = category_dfs['travel'].tokens.apply(generate_glove_embeddings)
em = pd.DataFrame(embedding1)
em.rename(columns = {'tokens':'embeddings'}, inplace = True)
embedding = category_dfs['travel'].copy()
embedding
final_df25 = pd.concat([em, embedding], axis = 1)
final_df25
# Out:
#                                               embeddings  target  \
# 0      [-0.08897043, -0.0015902787, -0.0074815345, -0...  travel
# 1      [0.019525371, 0.026340218, -0.009900642, 0.054...  travel
# 2      [0.0437402, -0.029157918, 0.014715543, 0.04680...  travel
# 3      [-0.06352922, 0.001389485, -0.023457803, -0.06...  travel
# 4      [-0.0067641144, -0.0074231494, 0.021509638, -0...  travel
# ...                                                  ...     ...
# 19907  [0.019525371, 0.0011394823, -0.019755138, -0.0...  travel
# 19908  [0.0011394823, -0.028558142, -0.014284893, 0.0...  travel
# 19909  [-0.0035659717, 0.031667084, -0.05478721, -0.0...  travel
# 19910  [-0.02208984, -0.056040343, 0.04185174, -0.085...  travel
# 19911  [0.0036411565, -0.01713799, -0.03640924, 0.009...  travel
#
#                                                   tokens
# 0      (james, beard, legendary, american, chef, writ...
# 1      (mumbai, online, travel, site, release, monthl...
# 2      (chennai, summer, several, train, chennai, alr...
# 3      (new, delhi, buoy, success, paisa, travel, ins...
# 4      (amenity, color, us, shock, guest, prefer, pay...
# ...                                                  ...
# 19907  (mumbai, second, consecutive, year, dubai, emi...
# 19908  (second, big, startup, hub, bengaluru, say, is...
# 19909  (annually, world, little, town, say, shires, r...
# 19910  (youre, talk, donna, think, thing, need, make,...
# 19911  (allahabad, special, court, mp, mla, wednesday...
#
# [19912 rows x 3 columns]

# %%
final_df25.to_csv("/content/drive/MyDrive/TIL/Word_Embeddings/travel_.csv")

# %%
category_dfs['video gaming']
embedding1 = category_dfs['video gaming'].tokens.apply(generate_glove_embeddings)
em = pd.DataFrame(embedding1)
em.rename(columns = {'tokens':'embeddings'}, inplace = True)
embedding = category_dfs['video gaming'].copy()
embedding
final_df26 = pd.concat([em, embedding], axis = 1)
final_df26
# Out:
#                                               embeddings        target  \
# 0      [0.024659358, -0.10918879, -0.033521418, -0.02...  video gaming
# 1      [0.006230319, -0.03893806, -0.06352922, 0.0302...  video gaming
# 2      [0.0, -0.012385723, 0.0, -0.0036891627, 0.0969...  video gaming
# 3      [0.0, 0.028791033, -0.013642687, -0.00282266, ...  video gaming
# 4      [-0.021043224, -0.023893595, -0.086239874, 0.0...  video gaming
# ...                                                  ...           ...
# 19937  [-0.01721782, 0.07121307, 0.0, 0.014257083, 0....  video gaming
# 19938  [0.0508124, -0.06962599, 0.07814604, 0.0224533...  video gaming
# 19939  [-0.0638693, 0.0067938687, -0.08596944, 0.0171...  video gaming
# 19940  [-0.08438859, 0.045592237, 0.0, -0.07062508, -...  video gaming
# 19941  [0.10501425, 0.031667084, 0.041790027, -0.0263...  video gaming
#
#                                                   tokens
# 0      (marvel, announce, next, big, spiderman, cross...
# 1      (unlike, many, new, release, dont, expect, chr...
# 2      (fathersin, addition, fourtime, champion, lang...
# 3      (gloomhaven, button, bug, reveal, surprise, ne...
# 4      (technology, use, political, communicationthos...
# ...                                                  ...
# 19937  (nagpur, akshay, zadgaonkar, child, prodigy, c...
# 19938  (bayonetta, lead, hideki, kamiya, reckons, lat...
# 19939  (al, pacino, think, original, godfather, well,...
# 19940  (late, episode, imlie, begin, aryan, receive, ...
# 19941  (entire, world, lockdown, various, degree, peo...
#
# [19942 rows x 3 columns]

# %%
final_df26.to_csv("/content/drive/MyDrive/TIL/Word_Embeddings/video_gaming_.csv")

# %%
df1=pd.read_csv("/content/drive/MyDrive/TIL/Word_Embeddings/academic_interests_.csv")
df2=pd.read_csv("/content/drive/MyDrive/TIL/Word_Embeddings/arts_and_culture_.csv")
df3=pd.read_csv("/content/drive/MyDrive/TIL/Word_Embeddings/automotives_.csv")
df4=pd.read_csv("/content/drive/MyDrive/TIL/Word_Embeddings/books_and_literature_.csv")
df5=pd.read_csv("/content/drive/MyDrive/TIL/Word_Embeddings/business_and_finance_.csv")
df6=pd.read_csv("/content/drive/MyDrive/TIL/Word_Embeddings/careers_.csv")
df7=pd.read_csv("/content/drive/MyDrive/TIL/Word_Embeddings/family_and_relationships_.csv")
df8=pd.read_csv("/content/drive/MyDrive/TIL/Word_Embeddings/food_and_drinks_.csv")
df9=pd.read_csv("/content/drive/MyDrive/TIL/Word_Embeddings/healthy_living_.csv")
df10=pd.read_csv("/content/drive/MyDrive/TIL/Word_Embeddings/health_.csv")
df11=pd.read_csv("/content/drive/MyDrive/TIL/Word_Embeddings/hobbies_and_interests_.csv")
df12=pd.read_csv("/content/drive/MyDrive/TIL/Word_Embeddings/home_and_garden.csv")
df13=pd.read_csv("/content/drive/MyDrive/TIL/Word_Embeddings/movies_.csv")
df14=pd.read_csv("/content/drive/MyDrive/TIL/Word_Embeddings/music_and_audio_.csv")
df15=pd.read_csv("/content/drive/MyDrive/TIL/Word_Embeddings/news_and_politics_.csv")
df16=pd.read_csv("/content/drive/MyDrive/TIL/Word_Embeddings/personal_and_finanace_.csv")
df17=pd.read_csv("/content/drive/MyDrive/TIL/Word_Embeddings/pets_.csv")
df18=pd.read_csv("/content/drive/MyDrive/TIL/Word_Embeddings/pharmaceuticals_conditions_and_symptoms_.csv")
df20=pd.read_csv("/content/drive/MyDrive/TIL/Word_Embeddings/real_estate_.csv")
df19=pd.read_csv("/content/drive/MyDrive/TIL/Word_Embeddings/shopping_.csv")
df21=pd.read_csv("/content/drive/MyDrive/TIL/Word_Embeddings/sports_.csv")
df22=pd.read_csv("/content/drive/MyDrive/TIL/Word_Embeddings/style_and_fashion_.csv")
df23=pd.read_csv("/content/drive/MyDrive/TIL/Word_Embeddings/technology_and_computing_.csv")
df24=pd.read_csv("/content/drive/MyDrive/TIL/Word_Embeddings/travel_.csv")
df25=pd.read_csv("/content/drive/MyDrive/TIL/Word_Embeddings/television_.csv")
df26=pd.read_csv("/content/drive/MyDrive/TIL/Word_Embeddings/video_gaming_.csv")

# %%
# List of all DataFrames
dfs = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17, df18, df19, df20, df21, df22, df23, df24, df25, df26]

# Combine DataFrames and reset index
_df = pd.concat(dfs, ignore_index=True)

_df
# Out:
#         Unnamed: 0                                         embeddings  \
# 0                0  [-0.06352922  0.00138948  0.09390125  0.109289...
# 1                1  [ 0.02738297  0.02035885 -0.06303439 -0.063529...
# 2                2  [ 1.63077712e-02 -5.72717227e-02 -7.62777478e-...
# 3                3  [ 8.2849739e-03 -2.2982287e-03 -8.8826463e-02 ...
# 4                4  [ 0.          0.05174642 -0.03536656 -0.021043...
# ...            ...                                                ...
# 517493       19937  [-0.01721782  0.07121307  0.          0.014257...
# 517494       19938  [ 0.0508124  -0.06962599  0.07814604  0.022453...
# 517495       19939  [-0.0638693   0.00679387 -0.08596944  0.017149...
# 517496       19940  [-0.08438859  0.04559224  0.         -0.070625...
# 517497       19941  [ 0.10501425  0.03166708  0.04179003 -0.026357...
#
#                     target                                             tokens
# 0       academic interests  ('new', 'delhi', 'andhra', 'pradesh', 'public'...
# 1       academic interests  ('pune', 'two', 'week', 'new', 'academic', 'ye...
# 2       academic interests  ('guwahati', 'result', 'cbse', 'class', 'x', '...
# 3       academic interests  ('admission', 'iims', 'say', 'kapoor', 'across...
# 4       academic interests  ('mangaluru', 'mangalore', 'institute', 'techn...
# ...                    ...                                                ...
# 517493        video gaming  ('nagpur', 'akshay', 'zadgaonkar', 'child', 'p...
# 517494        video gaming  ('bayonetta', 'lead', 'hideki', 'kamiya', 'rec...
# 517495        video gaming  ('al', 'pacino', 'think', 'original', 'godfath...
# 517496        video gaming  ('late', 'episode', 'imlie', 'begin', 'aryan',...
# 517497        video gaming  ('entire', 'world', 'lockdown', 'various', 'de...
#
# [517498 rows x 4 columns]

# %%
_df.to_csv("/content/drive/MyDrive/TIL/Word_Embeddings/_df_.csv")

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/TIL/Word_Embeddings/_df_.csv")
df
# Out:
#         Unnamed: 0.1  Unnamed: 0  \
# 0                  0           0
# 1                  1           1
# 2                  2           2
# 3                  3           3
# 4                  4           4
# ...              ...         ...
# 517493        517493       19937
# 517494        517494       19938
# 517495        517495       19939
# 517496        517496       19940
# 517497        517497       19941
#
#                                                embeddings              target  \
# 0       [-0.06352922  0.00138948  0.09390125  0.109289...  academic interests
# 1       [ 0.02738297  0.02035885 -0.06303439 -0.063529...  academic interests
# 2       [ 1.63077712e-02 -5.72717227e-02 -7.62777478e-...  academic interests
# 3       [ 8.2849739e-03 -2.2982287e-03 -8.8826463e-02 ...  academic interests
# 4       [ 0.          0.05174642 -0.03536656 -0.021043...  academic interests
# ...                                                   ...                 ...
# 517493  [-0.01721782  0.07121307  0.          0.014257...        video gaming
# 517494  [ 0.0508124  -0.06962599  0.07814604  0.022453...        video gaming
# 517495  [-0.0638693   0.00679387 -0.08596944  0.017149...        video gaming
# 517496  [-0.08438859  0.04559224  0.         -0.070625...        video gaming
# 517497  [ 0.10501425  0.03166708  0.04179003 -0.026357...        video gaming
#
#                                                    tokens
# 0       ('new', 'delhi', 'andhra', 'pradesh', 'public'...
# 1       ('pune', 'two', 'week', 'new', 'academic', 'ye...
# 2       ('guwahati', 'result', 'cbse', 'class', 'x', '...
# 3       ('admission', 'iims', 'say', 'kapoor', 'across...
# 4       ('mangaluru', 'mangalore', 'institute', 'techn...
# ...                                                   ...
# 517493  ('nagpur', 'akshay', 'zadgaonkar', 'child', 'p...
# 517494  ('bayonetta', 'lead', 'hideki', 'kamiya', 'rec...
# 517495  ('al', 'pacino', 'think', 'original', 'godfath...
# 517496  ('late', 'episode', 'imlie', 'begin', 'aryan',...
# 517497  ('entire', 'world', 'lockdown', 'various', 'de...
#
# [517498 rows x 5 columns]

# %%
# Drop the "Unnamed: 0" column
df = df.drop("Unnamed: 0.1", axis=1)

# %%
df = df.drop(columns=['tokens'])

# %%
df
# Out:
#         Unnamed: 0                                         embeddings  \
# 0                0  [-0.06352922  0.00138948  0.09390125  0.109289...
# 1                1  [ 0.02738297  0.02035885 -0.06303439 -0.063529...
# 2                2  [ 1.63077712e-02 -5.72717227e-02 -7.62777478e-...
# 3                3  [ 8.2849739e-03 -2.2982287e-03 -8.8826463e-02 ...
# 4                4  [ 0.          0.05174642 -0.03536656 -0.021043...
# ...            ...                                                ...
# 517493       19937  [-0.01721782  0.07121307  0.          0.014257...
# 517494       19938  [ 0.0508124  -0.06962599  0.07814604  0.022453...
# 517495       19939  [-0.0638693   0.00679387 -0.08596944  0.017149...
# 517496       19940  [-0.08438859  0.04559224  0.         -0.070625...
# 517497       19941  [ 0.10501425  0.03166708  0.04179003 -0.026357...
#
#                     target
# 0       academic interests
# 1       academic interests
# 2       academic interests
# 3       academic interests
# 4       academic interests
# ...                    ...
# 517493        video gaming
# 517494        video gaming
# 517495        video gaming
# 517496        video gaming
# 517497        video gaming
#
# [517498 rows x 3 columns]

# %%
import numpy as np
def convert_embeddings(embeddings):
  embeddings=embeddings.strip("[]")
  return np.array([float(value) for value in embeddings.split()])
df["embeddings"]=df["embeddings"].apply(convert_embeddings)

# %%
df
# Out:
#         Unnamed: 0                                         embeddings  \
# 0                0  [-0.06352922, 0.00138948, 0.09390125, 0.109289...
# 1                1  [0.02738297, 0.02035885, -0.06303439, -0.06352...
# 2                2  [0.0163077712, -0.0572717227, -0.0762777478, -...
# 3                3  [0.0082849739, -0.0022982287, -0.088826463, 0....
# 4                4  [0.0, 0.05174642, -0.03536656, -0.02104322, 0....
# ...            ...                                                ...
# 517493       19937  [-0.01721782, 0.07121307, 0.0, 0.01425708, 0.0...
# 517494       19938  [0.0508124, -0.06962599, 0.07814604, 0.0224533...
# 517495       19939  [-0.0638693, 0.00679387, -0.08596944, 0.017149...
# 517496       19940  [-0.08438859, 0.04559224, 0.0, -0.07062508, -0...
# 517497       19941  [0.10501425, 0.03166708, 0.04179003, -0.026357...
#
#                     target
# 0       academic interests
# 1       academic interests
# 2       academic interests
# 3       academic interests
# 4       academic interests
# ...                    ...
# 517493        video gaming
# 517494        video gaming
# 517495        video gaming
# 517496        video gaming
# 517497        video gaming
#
# [517498 rows x 3 columns]

# %%
X = df['embeddings']
y = df['target']

# %%
categories=df.target.unique()
categories
# Out:
# array(['academic interests', 'arts and culture', 'automotives',
#        'books and literature', 'business and finance', 'careers',
#        'family and relationships', 'food and drinks', 'healthy living',
#        'health', 'hobbies and interests', 'home and garden', 'movies',
#        'music and audio', 'news and politics', 'personal finance', 'pets',
#        'pharmaceuticals, conditions, and symptoms', 'shopping',
#        'real estate', 'sports', 'style and fashion',
#        'technology and computing', 'travel', 'television', 'video gaming'],
#       dtype=object)

# %%
sample_df = pd.DataFrame(columns=['embeddings', 'target'])
for category in categories:
    category_samples = df[df['target'] == category].sample(2000)
    sample_df = pd.concat([sample_df, category_samples])

sample_df.reset_index(drop=True, inplace=True)
sample_df
# Out:
#                                               embeddings              target  \
# 0      [-0.01174853, 0.03625012, -0.07089538, 0.02652...  academic interests
# 1      [-0.00763873, -0.06327738, -0.0002243, -0.0179...  academic interests
# 2      [0.01355462, -0.02325785, -0.03234862, 0.00307...  academic interests
# 3      [-0.02598906, -0.07737079, -0.07651789, 0.0677...  academic interests
# 4      [0.00138948, -0.05433779, -0.08179064, -0.0140...  academic interests
# ...                                                  ...                 ...
# 51995  [0.00735696, -0.01887533, 0.01385185, -0.02508...        video gaming
# 51996  [0.0, 0.00466237, 0.04778038, -0.0397411, -0.0...        video gaming
# 51997  [0.01431744, 0.00363123, 0.0, -0.05675694, 0.0...        video gaming
# 51998  [-0.08367307, -0.08882646, 0.0422884, 0.031815...        video gaming
# 51999  [-0.01412074, 0.01681493, 0.03469527, -0.09798...        video gaming
#
#        Unnamed: 0
# 0          6238.0
# 1          3295.0
# 2         10644.0
# 3         10470.0
# 4          6869.0
# ...           ...
# 51995     19742.0
# 51996      2825.0
# 51997     12783.0
# 51998      3382.0
# 51999     10889.0
#
# [52000 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split

# Assuming your DataFrame is named 'df' and the target column is named 'target'
X = sample_df['embeddings'].values  # Features (all columns except the target)
y = sample_df['target'].values  # Target column

# Split the data while ensuring equal distribution of target values
# X_train, X_test, y_train, y_test = train_test_split(X, y,train_size=0.75, stratify=y, random_state=42)

# Now, X_train, X_test, y_train, and y_test contain your training and testing data

# %%
max_length = max(len(seq) for seq in X)
max_length
# Out:
# 500

# %%
padded_x = []
for seq in X:
    seq_len = len(seq)
    padded_seq = np.pad(seq, (0, max_length - seq_len), constant_values=0.0)
    padded_x.append(padded_seq)

padded_x = np.array(padded_x, dtype=np.float32)
padded_x
# Out:
# array([[-0.01174853,  0.03625012, -0.07089538, ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.00763873, -0.06327738, -0.0002243 , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.01355462, -0.02325785, -0.03234862, ...,  0.        ,
#          0.        ,  0.        ],
#        ...,
#        [ 0.01431744,  0.00363123,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.08367307, -0.08882646,  0.0422884 , ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.01412074,  0.01681493,  0.03469527, ...,  0.        ,
#          0.        ,  0.        ]], dtype=float32)

# %%
padded_x.shape
# Out:
# (52000, 500)

# %%
# Split the data while ensuring equal distribution of target values
X_train, X_test, y_train, y_test = train_test_split(padded_x, y,train_size=0.80, stratify=y, random_state=42)

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

# Create an SVM classifier with a linear kernel (you can adjust the kernel and C parameter)
svm_classifier = SVC(kernel='linear', C=6)

# %%
# Fit the classifier on the training data
svm_classifier.fit(X_train, y_train)

# Make predictions on the testing data
y_pred = svm_classifier.predict(X_test)
