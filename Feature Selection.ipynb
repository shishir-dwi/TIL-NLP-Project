# %%
import numpy as np
import pandas as pd
import ast
import torch
from transformers import BertModel, BertTokenizer

# %%
preprocessed_df = pd.read_csv('preprocessed_sample_df.csv')
preprocessed_df
# Out:
#                                                      text              target  \
# 0       last summer my granddaughter brooke played in ...  academic interests
# 1       new delhi uttar pradesh police recruitment boa...  academic interests
# 2        belgaum karnataka higher education minister c...  academic interests
# 3        lincoln university has welcomed the governmen...  academic interests
# 4       new delhi the uttar pradesh public service com...  academic interests
# ...                                                   ...                 ...
# 517707   death stranding  has been announced at the ga...        video gaming
# 517708  raj kundra dons multiple hats but one thing th...        video gaming
# 517709   mario  rabbids sparks of hope one of the best...        video gaming
# 517710  ahmedabad a yearold man from adalaj who marrie...        video gaming
# 517711  actress varada jishin is multitasking by being...        video gaming
#
#                                                    tokens
# 0       ['last', 'summer', 'granddaughter', 'brooke', ...
# 1       ['new', 'delhi', 'uttar', 'pradesh', 'police',...
# 2       ['belgaum', 'karnataka', 'high', 'education', ...
# 3       ['lincoln', 'university', 'welcome', 'governme...
# 4       ['new', 'delhi', 'uttar', 'pradesh', 'public',...
# ...                                                   ...
# 517707  ['death', 'stranding', 'announce', 'game', 'aw...
# 517708  ['raj', 'kundra', 'don', 'multiple', 'hat', 'o...
# 517709  ['mario', 'rabbids', 'spark', 'hope', 'one', '...
# 517710  ['ahmedabad', 'yearold', 'man', 'adalaj', 'mar...
# 517711  ['actress', 'varada', 'jishin', 'multitasking'...
#
# [517712 rows x 3 columns]

# %%
preprocessed_df.iloc[0].tokens
# Out:
# "['last', 'summer', 'granddaughter', 'brooke', 'play', 'us', 'kid', 'golf', 'world', 'championship', 'pinehurst', 'north', 'carolina', 'pay', 'think', 'inside', 'box']"

# %%
preprocessed_df.tokens = preprocessed_df.tokens.apply(ast.literal_eval)

# %% [markdown]
# ## Sampling code for generating word embeddings using 'bert-base-uncased' model

# %%
sample = preprocessed_df.head(100)
sample
# Out:
#                                                  text              target  \
# 0   last summer my granddaughter brooke played in ...  academic interests
# 1   new delhi uttar pradesh police recruitment boa...  academic interests
# 2    belgaum karnataka higher education minister c...  academic interests
# 3    lincoln university has welcomed the governmen...  academic interests
# 4   new delhi the uttar pradesh public service com...  academic interests
# ..                                                ...                 ...
# 95  visakhapatnam apprehensive parents of students...  academic interests
# 96  new delhi the kartet answer key  has been rele...  academic interests
# 97  ahmedabad the new education policy nep has bee...  academic interests
# 98  new delhi defence research  development organi...  academic interests
# 99  new delhi national testing agency nta conducte...  academic interests
#
#                                                tokens
# 0   [last, summer, granddaughter, brooke, play, us...
# 1   [new, delhi, uttar, pradesh, police, recruitme...
# 2   [belgaum, karnataka, high, education, minister...
# 3   [lincoln, university, welcome, government, dec...
# 4   [new, delhi, uttar, pradesh, public, service, ...
# ..                                                ...
# 95  [visakhapatnam, apprehensive, parent, student,...
# 96  [new, delhi, kartet, answer, key, release, nov...
# 97  [ahmedabad, new, education, policy, nep, prepa...
# 98  [new, delhi, defence, research, development, o...
# 99  [new, delhi, national, testing, agency, nta, c...
#
# [100 rows x 3 columns]

# %%
model = BertModel.from_pretrained('bert-base-uncased')
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
def generate_embeddings(token):
    token_ids = tokenizer.encode(token, add_special_tokens=True, max_length=512, return_tensors='pt', truncation=True)
    
    with torch.no_grad():
        outputs = model(token_ids)
        token_embeddings = outputs.last_hidden_state
#     token_embeddings = token_embeddings.numpy()
    
    return token_embeddings

# %%
sample['embeddings'] = sample['tokens'].apply(generate_embeddings)
sample
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_11588\1270046980.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample['embeddings'] = sample['tokens'].apply(generate_embeddings)
#                                                  text              target  \
# 0   last summer my granddaughter brooke played in ...  academic interests
# 1   new delhi uttar pradesh police recruitment boa...  academic interests
# 2    belgaum karnataka higher education minister c...  academic interests
# 3    lincoln university has welcomed the governmen...  academic interests
# 4   new delhi the uttar pradesh public service com...  academic interests
# ..                                                ...                 ...
# 95  visakhapatnam apprehensive parents of students...  academic interests
# 96  new delhi the kartet answer key  has been rele...  academic interests
# 97  ahmedabad the new education policy nep has bee...  academic interests
# 98  new delhi defence research  development organi...  academic interests
# 99  new delhi national testing agency nta conducte...  academic interests
#
#                                                tokens  \
# 0   [last, summer, granddaughter, brooke, play, us...
# 1   [new, delhi, uttar, pradesh, police, recruitme...
# 2   [belgaum, karnataka, high, education, minister...
# 3   [lincoln, university, welcome, government, dec...
# 4   [new, delhi, uttar, pradesh, public, service, ...
# ..                                                ...
# 95  [visakhapatnam, apprehensive, parent, student,...
# 96  [new, delhi, kartet, answer, key, release, nov...
# 97  [ahmedabad, new, education, policy, nep, prepa...
# 98  [new, delhi, defence, research, development, o...
# 99  [new, delhi, national, testing, agency, nta, c...
#
#                                            embeddings
# 0   [[[tensor(-0.0398), tensor(0.0898), tensor(0.2...
# 1   [[[tensor(-0.0948), tensor(0.0705), tensor(0.0...
# 2   [[[tensor(-0.0959), tensor(0.0608), tensor(0.1...
# 3   [[[tensor(0.1248), tensor(0.2531), tensor(0.22...
# 4   [[[tensor(-0.3586), tensor(0.0036), tensor(-0....
# ..                                                ...
# 95  [[[tensor(0.0386), tensor(0.2406), tensor(0.09...
# 96  [[[tensor(-0.0935), tensor(0.1588), tensor(0.1...
# 97  [[[tensor(-0.1235), tensor(-0.0790), tensor(0....
# 98  [[[tensor(-0.0390), tensor(0.1840), tensor(0.0...
# 99  [[[tensor(-0.1135), tensor(0.1638), tensor(0.1...
#
# [100 rows x 4 columns]

# %%
sample.iloc[0].embeddings
# Out:
# tensor([[[-0.0398,  0.0898,  0.2421,  ..., -0.3452,  0.1710,  0.1143],
#          [-0.5097, -0.8875,  0.5615,  ..., -0.3648,  0.1800,  0.1951],
#          [-0.1292,  0.2927,  0.0892,  ..., -0.7827,  0.0801, -0.8439],
#          ...,
#          [ 0.3515, -0.3867,  0.6344,  ...,  0.0792,  0.3978, -0.3380],
#          [ 0.0046, -0.3359,  0.2507,  ...,  0.0475, -0.0955,  0.0109],
#          [ 0.4190,  0.3783, -0.0905,  ...,  0.0106, -0.6071, -0.1755]]])

# %% [markdown]
# ## Generating Word Embeddings for each category using BERT

# %%
preprocessed_df['target'].unique()
# Out:
# array(['academic interests', 'arts and culture', 'automotive',
#        'books and literature', 'business and finance', 'careers',
#        'family and relationships', 'food and drink', 'health',
#        'healthy living', 'hobbies and interests', 'home and garden',
#        'movies', 'music and audio', 'news and politics',
#        'personal finance', 'pets',
#        'pharmaceuticals, conditions, and symptoms', 'real estate',
#        'shopping', 'sports', 'style and fashion',
#        'technology and computing', 'television', 'travel', 'video gaming'],
#       dtype=object)

# %%
def category_dataframes(preprocessed_df):
   
    unique_categories = preprocessed_df['target'].unique()
    
    category_dataframes = {}
    
    for category in unique_categories:
        filtered_df = preprocessed_df[preprocessed_df['target'] == category].copy()
        filtered_df.reset_index(drop=True, inplace=True)
        category_dataframes[category] = filtered_df

    return category_dataframes

category_dfs = category_dataframes(preprocessed_df)

# %% [markdown]
# #### ACADEMIC INTERESTS

# %%
category_dfs['academic interests']
# Out:
#                                                     text              target  \
# 0      last summer my granddaughter brooke played in ...  academic interests
# 1      new delhi uttar pradesh police recruitment boa...  academic interests
# 2       belgaum karnataka higher education minister c...  academic interests
# 3       lincoln university has welcomed the governmen...  academic interests
# 4      new delhi the uttar pradesh public service com...  academic interests
# ...                                                  ...                 ...
# 19995  the admission committee for professional under...  academic interests
# 19996  new delhi a virtual meeting of g education min...  academic interests
# 19997  jaipur anil a devoted fifth grade student of a...  academic interests
# 19998   jayanti bharadwaj final year psychology honou...  academic interests
# 19999  trichy the district education department has a...  academic interests
#
#                                                   tokens
# 0      [last, summer, granddaughter, brooke, play, us...
# 1      [new, delhi, uttar, pradesh, police, recruitme...
# 2      [belgaum, karnataka, high, education, minister...
# 3      [lincoln, university, welcome, government, dec...
# 4      [new, delhi, uttar, pradesh, public, service, ...
# ...                                                  ...
# 19995  [admission, committee, professional, undergrad...
# 19996  [new, delhi, virtual, meeting, g, education, m...
# 19997  [jaipur, anil, devote, fifth, grade, student, ...
# 19998  [jayanti, bharadwaj, final, year, psychology, ...
# 19999  [trichy, district, education, department, add,...
#
# [20000 rows x 3 columns]

# %%
embed1 = category_dfs['academic interests'].tokens.apply(generate_embeddings)

# %%
embed1
# Out:
# 0        [[[tensor(-0.0398), tensor(0.0898), tensor(0.2...
# 1        [[[tensor(-0.0948), tensor(0.0705), tensor(0.0...
# 2        [[[tensor(-0.0959), tensor(0.0608), tensor(0.1...
# 3        [[[tensor(0.1248), tensor(0.2531), tensor(0.22...
# 4        [[[tensor(-0.3586), tensor(0.0036), tensor(-0....
#                                ...
# 19995    [[[tensor(-0.1531), tensor(0.2153), tensor(-0....
# 19996    [[[tensor(0.0786), tensor(0.2683), tensor(0.11...
# 19997    [[[tensor(0.1589), tensor(-0.0967), tensor(0.1...
# 19998    [[[tensor(0.0722), tensor(0.2184), tensor(0.15...
# 19999    [[[tensor(-0.0039), tensor(0.0708), tensor(0.4...
# Name: tokens, Length: 20000, dtype: object

# %%
em = pd.DataFrame(embed1)
em
# Out:
#                                                   tokens
# 0      [[[tensor(-0.0398), tensor(0.0898), tensor(0.2...
# 1      [[[tensor(-0.0948), tensor(0.0705), tensor(0.0...
# 2      [[[tensor(-0.0959), tensor(0.0608), tensor(0.1...
# 3      [[[tensor(0.1248), tensor(0.2531), tensor(0.22...
# 4      [[[tensor(-0.3586), tensor(0.0036), tensor(-0....
# ...                                                  ...
# 19995  [[[tensor(-0.1531), tensor(0.2153), tensor(-0....
# 19996  [[[tensor(0.0786), tensor(0.2683), tensor(0.11...
# 19997  [[[tensor(0.1589), tensor(-0.0967), tensor(0.1...
# 19998  [[[tensor(0.0722), tensor(0.2184), tensor(0.15...
# 19999  [[[tensor(-0.0039), tensor(0.0708), tensor(0.4...
#
# [20000 rows x 1 columns]

# %%
em.rename(columns = {'tokens':'embeddings'}, inplace = True)
em
# Out:
#                                               embeddings
# 0      [[[tensor(-0.0398), tensor(0.0898), tensor(0.2...
# 1      [[[tensor(-0.0948), tensor(0.0705), tensor(0.0...
# 2      [[[tensor(-0.0959), tensor(0.0608), tensor(0.1...
# 3      [[[tensor(0.1248), tensor(0.2531), tensor(0.22...
# 4      [[[tensor(-0.3586), tensor(0.0036), tensor(-0....
# ...                                                  ...
# 19995  [[[tensor(-0.1531), tensor(0.2153), tensor(-0....
# 19996  [[[tensor(0.0786), tensor(0.2683), tensor(0.11...
# 19997  [[[tensor(0.1589), tensor(-0.0967), tensor(0.1...
# 19998  [[[tensor(0.0722), tensor(0.2184), tensor(0.15...
# 19999  [[[tensor(-0.0039), tensor(0.0708), tensor(0.4...
#
# [20000 rows x 1 columns]

# %%
embed = category_dfs['academic interests'].copy()
embed
# Out:
#                                                     text              target  \
# 0      last summer my granddaughter brooke played in ...  academic interests
# 1      new delhi uttar pradesh police recruitment boa...  academic interests
# 2       belgaum karnataka higher education minister c...  academic interests
# 3       lincoln university has welcomed the governmen...  academic interests
# 4      new delhi the uttar pradesh public service com...  academic interests
# ...                                                  ...                 ...
# 19995  the admission committee for professional under...  academic interests
# 19996  new delhi a virtual meeting of g education min...  academic interests
# 19997  jaipur anil a devoted fifth grade student of a...  academic interests
# 19998   jayanti bharadwaj final year psychology honou...  academic interests
# 19999  trichy the district education department has a...  academic interests
#
#                                                   tokens
# 0      [last, summer, granddaughter, brooke, play, us...
# 1      [new, delhi, uttar, pradesh, police, recruitme...
# 2      [belgaum, karnataka, high, education, minister...
# 3      [lincoln, university, welcome, government, dec...
# 4      [new, delhi, uttar, pradesh, public, service, ...
# ...                                                  ...
# 19995  [admission, committee, professional, undergrad...
# 19996  [new, delhi, virtual, meeting, g, education, m...
# 19997  [jaipur, anil, devote, fifth, grade, student, ...
# 19998  [jayanti, bharadwaj, final, year, psychology, ...
# 19999  [trichy, district, education, department, add,...
#
# [20000 rows x 3 columns]

# %%
final_df = pd.concat([em, embed], axis = 1)
final_df

# %%
final_df
# Out:
#                                               embeddings  \
# 0      [[[tensor(-0.0398), tensor(0.0898), tensor(0.2...
# 1      [[[tensor(-0.0948), tensor(0.0705), tensor(0.0...
# 2      [[[tensor(-0.0959), tensor(0.0608), tensor(0.1...
# 3      [[[tensor(0.1248), tensor(0.2531), tensor(0.22...
# 4      [[[tensor(-0.3586), tensor(0.0036), tensor(-0....
# ...                                                  ...
# 19995  [[[tensor(-0.1531), tensor(0.2153), tensor(-0....
# 19996  [[[tensor(0.0786), tensor(0.2683), tensor(0.11...
# 19997  [[[tensor(0.1589), tensor(-0.0967), tensor(0.1...
# 19998  [[[tensor(0.0722), tensor(0.2184), tensor(0.15...
# 19999  [[[tensor(-0.0039), tensor(0.0708), tensor(0.4...
#
#                                                     text              target  \
# 0      last summer my granddaughter brooke played in ...  academic interests
# 1      new delhi uttar pradesh police recruitment boa...  academic interests
# 2       belgaum karnataka higher education minister c...  academic interests
# 3       lincoln university has welcomed the governmen...  academic interests
# 4      new delhi the uttar pradesh public service com...  academic interests
# ...                                                  ...                 ...
# 19995  the admission committee for professional under...  academic interests
# 19996  new delhi a virtual meeting of g education min...  academic interests
# 19997  jaipur anil a devoted fifth grade student of a...  academic interests
# 19998   jayanti bharadwaj final year psychology honou...  academic interests
# 19999  trichy the district education department has a...  academic interests
#
#                                                   tokens
# 0      [last, summer, granddaughter, brooke, play, us...
# 1      [new, delhi, uttar, pradesh, police, recruitme...
# 2      [belgaum, karnataka, high, education, minister...
# 3      [lincoln, university, welcome, government, dec...
# 4      [new, delhi, uttar, pradesh, public, service, ...
# ...                                                  ...
# 19995  [admission, committee, professional, undergrad...
# 19996  [new, delhi, virtual, meeting, g, education, m...
# 19997  [jaipur, anil, devote, fifth, grade, student, ...
# 19998  [jayanti, bharadwaj, final, year, psychology, ...
# 19999  [trichy, district, education, department, add,...
#
# [20000 rows x 4 columns]

# %%
final_df.to_csv('final_df.csv', index = False)

# %% [markdown]
# #### AUTOMOTIVE

# %%
embed2 = category_dfs['automotive'].copy()
embed2
# Out:
#                                                     text      target  \
# 0      five stars extended vision poor not a secure f...  automotive
# 1      good the air conditioner in my gti had a horri...  automotive
# 2      its working fine  i really like the shutoff ti...  automotive
# 3      did not work for us bummer deal dificult to mo...  automotive
# 4      does a great job truly great product a must ha...  automotive
# ...                                                  ...         ...
# 19995  overpriced with short life span five stars i w...  automotive
# 19996  compact cooler great product proper v ac adapt...  automotive
# 19997  s top cleaner and conditioner yes and no amazi...  automotive
# 19998  does not fit does not fit my  chrysler voyager...  automotive
# 19999  cars should come with these things great addon...  automotive
#
#                                                   tokens
# 0      [five, star, extend, vision, poor, secure, fit...
# 1      [good, air, conditioner, gti, horrible, smell,...
# 2      [work, fine, really, like, shutoff, timer, war...
# 3      [work, us, bummer, deal, dificult, mount, vibr...
# 4      [great, job, truly, great, product, must, amaz...
# ...                                                  ...
# 19995  [overprice, short, life, span, five, star, wis...
# 19996  [compact, cooler, great, product, proper, v, a...
# 19997  [top, cleaner, conditioner, yes, amaze, stuff,...
# 19998  [fit, fit, chrysler, voyager, fit, dodge, stra...
# 19999  [car, come, thing, great, addon, easy, install...
#
# [20000 rows x 3 columns]

# %%
empty_list_mask = embed2['tokens'].apply(lambda x: len(x) == 0)
embed2 = embed2[~empty_list_mask]
embed2.reset_index(drop=True, inplace=True)

# %%
embed2['embeddings'] = embed2['tokens'].apply(generate_embeddings)
embed2
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_11588\328177648.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   embed2['embeddings'] = embed2['tokens'].apply(generate_embeddings)
#                                                     text      target  \
# 0      five stars extended vision poor not a secure f...  automotive
# 1      good the air conditioner in my gti had a horri...  automotive
# 2      its working fine  i really like the shutoff ti...  automotive
# 3      did not work for us bummer deal dificult to mo...  automotive
# 4      does a great job truly great product a must ha...  automotive
# ...                                                  ...         ...
# 19994  overpriced with short life span five stars i w...  automotive
# 19995  compact cooler great product proper v ac adapt...  automotive
# 19996  s top cleaner and conditioner yes and no amazi...  automotive
# 19997  does not fit does not fit my  chrysler voyager...  automotive
# 19998  cars should come with these things great addon...  automotive
#
#                                                   tokens  \
# 0      [five, star, extend, vision, poor, secure, fit...
# 1      [good, air, conditioner, gti, horrible, smell,...
# 2      [work, fine, really, like, shutoff, timer, war...
# 3      [work, us, bummer, deal, dificult, mount, vibr...
# 4      [great, job, truly, great, product, must, amaz...
# ...                                                  ...
# 19994  [overprice, short, life, span, five, star, wis...
# 19995  [compact, cooler, great, product, proper, v, a...
# 19996  [top, cleaner, conditioner, yes, amaze, stuff,...
# 19997  [fit, fit, chrysler, voyager, fit, dodge, stra...
# 19998  [car, come, thing, great, addon, easy, install...
#
#                                               embeddings
# 0      [[[tensor(-0.5493), tensor(-0.2083), tensor(0....
# 1      [[[tensor(-0.2094), tensor(0.3140), tensor(-0....
# 2      [[[tensor(-0.1737), tensor(-0.0404), tensor(0....
# 3      [[[tensor(0.0072), tensor(0.4846), tensor(-0.1...
# 4      [[[tensor(-0.0311), tensor(0.2784), tensor(-0....
# ...                                                  ...
# 19994  [[[tensor(0.1238), tensor(-0.1887), tensor(0.0...
# 19995  [[[tensor(-0.6659), tensor(0.2869), tensor(0.0...
# 19996  [[[tensor(-0.0725), tensor(0.1614), tensor(-0....
# 19997  [[[tensor(-0.6109), tensor(-0.0556), tensor(0....
# 19998  [[[tensor(-0.2643), tensor(0.3651), tensor(-0....
#
# [19999 rows x 4 columns]

# %%
final_df = pd.concat([final_df, embed2], axis = 0)

# %%
final_df
# Out:
#                                               embeddings  \
# 0      tensor([[[-0.0398,  0.0898,  0.2421,  ..., -0....
# 1      tensor([[[-0.0948,  0.0705,  0.0733,  ..., -0....
# 2      tensor([[[-0.0959,  0.0608,  0.1507,  ..., -0....
# 3      tensor([[[ 0.1248,  0.2531,  0.2269,  ..., -0....
# 4      tensor([[[-3.5864e-01,  3.5984e-03, -3.4623e-0...
# ...                                                  ...
# 19994  [[[tensor(0.1238), tensor(-0.1887), tensor(0.0...
# 19995  [[[tensor(-0.6659), tensor(0.2869), tensor(0.0...
# 19996  [[[tensor(-0.0725), tensor(0.1614), tensor(-0....
# 19997  [[[tensor(-0.6109), tensor(-0.0556), tensor(0....
# 19998  [[[tensor(-0.2643), tensor(0.3651), tensor(-0....
#
#                                                     text              target  \
# 0      last summer my granddaughter brooke played in ...  academic interests
# 1      new delhi uttar pradesh police recruitment boa...  academic interests
# 2       belgaum karnataka higher education minister c...  academic interests
# 3       lincoln university has welcomed the governmen...  academic interests
# 4      new delhi the uttar pradesh public service com...  academic interests
# ...                                                  ...                 ...
# 19994  overpriced with short life span five stars i w...          automotive
# 19995  compact cooler great product proper v ac adapt...          automotive
# 19996  s top cleaner and conditioner yes and no amazi...          automotive
# 19997  does not fit does not fit my  chrysler voyager...          automotive
# 19998  cars should come with these things great addon...          automotive
#
#                                                   tokens
# 0      ['last', 'summer', 'granddaughter', 'brooke', ...
# 1      ['new', 'delhi', 'uttar', 'pradesh', 'police',...
# 2      ['belgaum', 'karnataka', 'high', 'education', ...
# 3      ['lincoln', 'university', 'welcome', 'governme...
# 4      ['new', 'delhi', 'uttar', 'pradesh', 'public',...
# ...                                                  ...
# 19994  [overprice, short, life, span, five, star, wis...
# 19995  [compact, cooler, great, product, proper, v, a...
# 19996  [top, cleaner, conditioner, yes, amaze, stuff,...
# 19997  [fit, fit, chrysler, voyager, fit, dodge, stra...
# 19998  [car, come, thing, great, addon, easy, install...
#
# [39999 rows x 4 columns]

# %%
final_df.to_csv('final_df.csv', index = False)

# %% [markdown]
# #### BOOKS AND LITERATURE

# %%
def generate_embeddings_batch(token):
    token_ids = [tokenizer.encode(sent, add_special_tokens=True, max_length=512, truncation=True) for sent in token]

    max_seq_length = max(len(tokens) for tokens in token_ids)
    token_ids = [tokens + [tokenizer.pad_token_id] * (max_seq_length - len(tokens)) for tokens in token_ids]
    token_ids = torch.tensor(token_ids, dtype=torch.long)

    with torch.no_grad():
        outputs = model(token_ids, return_dict=True)
        token_embeddings = outputs.last_hidden_state
    token_embeddings = token_embeddings.numpy()
    
    return token_embeddings

# %%
embed3 = category_dfs['books and literature'].copy()
empty_list_mask = embed3['tokens'].apply(lambda x: len(x) == 0)
embed3 = embed3[~empty_list_mask]
embed3.reset_index(drop=True, inplace=True)

# %%
batch_size = 32
batches = [embed3['tokens'][i:i + batch_size] for i in range(0, len(embed3), batch_size)]

embeddings_list = []

for batch in batches:
    token_embeddings_batch = generate_embeddings_batch(batch)
    embeddings_list.append(token_embeddings_batch)

token_embeddings_all = np.concatenate(embeddings_list, axis=0)
embed2['embeddings'] = token_embeddings_all.tolist()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11588\3033366225.py in <module>
#       5
#       6 for batch in batches:
# ----> 7     token_embeddings_batch = generate_embeddings_batch(batch)
#       8     embeddings_list.append(token_embeddings_batch)
#       9
#
# ~\AppData\Local\Temp\ipykernel_11588\1874302567.py in generate_embeddings_batch(token)
#       7
#       8     with torch.no_grad():
# ----> 9         outputs = model(token_ids, return_dict=True)
#      10         token_embeddings = outputs.last_hidden_state
#      11     token_embeddings = token_embeddings.numpy()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\transformers\models\bert\modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1018             past_key_values_length=past_key_values_length,
#    1019         )
# -> 1020         encoder_outputs = self.encoder(
#    1021             embedding_output,
#    1022             attention_mask=extended_attention_mask,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\transformers\models\bert\modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     608                 )
#     609             else:
# --> 610                 layer_outputs = layer_module(
#     611                     hidden_states,
#     612                     attention_mask,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\transformers\models\bert\modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     493         # decoder uni-directional self-attention cached key/values tuple is at positions 1,2
#     494         self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
# --> 495         self_attention_outputs = self.attention(
#     496             hidden_states,
#     497             attention_mask,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\transformers\models\bert\modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     423         output_attentions: Optional[bool] = False,
#     424     ) -> Tuple[torch.Tensor]:
# --> 425         self_outputs = self.self(
#     426             hidden_states,
#     427             attention_mask,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\transformers\models\bert\modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     361             attention_probs = attention_probs * head_mask
#     362
# --> 363         context_layer = torch.matmul(attention_probs, value_layer)
#     364
#     365         context_layer = context_layer.permute(0, 2, 1, 3).contiguous()
#
# RuntimeError: [enforce fail at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\c10\core\impl\alloc_cpu.cpp:72] data. DefaultCPUAllocator: not enough memory: you tried to allocate 46301184 bytes.

# %%
len(embeddings_list)
# Out:
# 232
